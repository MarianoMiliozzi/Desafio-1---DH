# %%
import numpy as np              ;   import pandas as pd
import geopandas as gpd         ;   from shapely.geometry import Polygon, Point, LineString
import shapely as sp            ;   import matplotlib.pyplot as plt
import time                     ;   import unidecode
import re

startAll = time.time()
def t():
    global start
    start = time.time()
def tt():
    end = time.time() ; minutos = int(round(end - start)/60) ; segundos = int(round(end - start)-(int(round(end - start)/60))*60) ;     tiempo = 'Esta celda tardo en ejecutar: '+str(minutos)+' minutos, '+str(segundos)+' segundos.' ;
    return tiempo
def tiempo():
    endAll = time.time() ; minutos = int(round(endAll - startAll)/60) ; segundos = int(round(endAll - startAll)-(int(round(endAll - startAll)/60))*60) ;     tiempo = 'Desde el inicio, tardo en ejecutar: '+str(minutos)+' minutos, '+str(segundos)+' segundos.' ;
    return tiempo

# %% [markdown]
# # PROPERATTI DATABASE

# %%
ls
# Out:
#  Volume in drive C is SYSTEM2
#  Volume Serial Number is 70F1-0DE5
#
#  Directory of C:\Users\Manu\OneDrive\DH_Dscience\Clase06_Desafio
#
# 04/02/2020  05:37 PM    <DIR>          .
# 04/02/2020  05:37 PM    <DIR>          ..
# 04/02/2020  12:45 PM    <DIR>          .ipynb_checkpoints
# 04/02/2020  05:34 PM            10,847 Boxplot.png
# 03/22/2020  02:40 PM    <DIR>          carto
# 04/02/2020  05:34 PM        14,522,348 df_limpio.csv
# 04/02/2020  03:45 PM    <DIR>          documentacion
# 04/01/2020  08:55 PM           162,119 geo_visualizacion_para juntar.ipynb
# 04/02/2020  05:34 PM            11,569 Histograma seaborn.png
# 04/02/2020  05:34 PM            11,196 Histograma.png
# 04/02/2020  03:34 PM         2,956,329 limpieza_espacial.ipynb
# 04/02/2020  03:50 PM         3,938,940 nulos_plot_&_m2.ipynb
# 04/02/2020  04:41 PM    <DIR>          PPT
# 04/02/2020  05:33 PM         6,886,939 Properati Desaf¡o 1 - Grupo 1.ipynb
# 04/02/2020  05:32 PM    <DIR>          properati_geoshape
# 07/05/2018  10:51 AM       149,311,692 properatti.csv
# 04/02/2020  05:30 PM           373,336 Rooms.ipynb
# 04/02/2020  03:45 PM    <DIR>          trash
#               10 File(s)    178,185,315 bytes
#                8 Dir(s)  101,287,473,152 bytes free

# %%
df = pd.read_csv('properatti.csv',sep=',',index_col=0)
df.shape
# Out:
# (121220, 25)

# %%
len(df.property_type.unique())
# Out:
# 4

# %%
df.head(2)
# Out:
#   operation property_type place_name  \
# 0      sell            PH  Mataderos
# 1      sell     apartment   La Plata
#
#                        place_with_parent_names country_name  \
# 0        |Argentina|Capital Federal|Mataderos|    Argentina
# 1  |Argentina|Bs.As. G.B.A. Zona Sur|La Plata|    Argentina
#
#                state_name  geonames_id                  lat-lon        lat  \
# 0         Capital Federal    3430787.0  -34.6618237,-58.5088387 -34.661824
# 1  Bs.As. G.B.A. Zona Sur    3432039.0  -34.9038831,-57.9643295 -34.903883
#
#          lon  ...  surface_covered_in_m2 price_usd_per_m2  price_per_m2  \
# 0 -58.508839  ...                   40.0      1127.272727        1550.0
# 1 -57.964330  ...                    NaN              NaN           NaN
#
#    floor  rooms  expenses                                      properati_url  \
# 0    NaN    NaN       NaN  http://www.properati.com.ar/15bo8_venta_ph_mat...
# 1    NaN    NaN       NaN  http://www.properati.com.ar/15bob_venta_depart...
#
#                                          description  \
# 0  2 AMBIENTES TIPO CASA PLANTA BAJA POR PASILLO,...
# 1  Venta de departamento en décimo piso al frente...
#
#                                                title  \
# 0                 2 AMB TIPO CASA SIN EXPENSAS EN PB
# 1  VENTA Depto 2 dorm. a estrenar 7 e/ 36 y 37   ...
#
#                                      image_thumbnail
# 0  https://thumbs4.properati.com/8/BluUYiHJLhgIIK...
# 1  https://thumbs4.properati.com/7/ikpVBu2ztHA7jv...
#
# [2 rows x 25 columns]

# %% [markdown]
# # LLAVE Primaria
# se encuentra en la direccion URL un codigo embebido que distingue cada registro individualmente

# %%
df.properati_url.iloc[0]
# Out:
# 'http://www.properati.com.ar/15bo8_venta_ph_mataderos_lavadero_patio_inmobiliaria-fedele'

# %%
'http://www.properati.com.ar/15bo8_.......'
# Out:
# 'http://www.properati.com.ar/15bo8_.......'

# %%
def get_codigo(data):
    data = data.strip('http://www.properati.com.ar/')
    return data.split('_')[0]

# %%
df['id'] = df.properati_url.map(get_codigo)

# %%
len(df.id.unique()) == df.shape[0]
# Out:
# True

# %%
df.head(2)
# Out:
#   operation property_type place_name  \
# 0      sell            PH  Mataderos
# 1      sell     apartment   La Plata
#
#                        place_with_parent_names country_name  \
# 0        |Argentina|Capital Federal|Mataderos|    Argentina
# 1  |Argentina|Bs.As. G.B.A. Zona Sur|La Plata|    Argentina
#
#                state_name  geonames_id                  lat-lon        lat  \
# 0         Capital Federal    3430787.0  -34.6618237,-58.5088387 -34.661824
# 1  Bs.As. G.B.A. Zona Sur    3432039.0  -34.9038831,-57.9643295 -34.903883
#
#          lon  ...  price_usd_per_m2 price_per_m2  floor  rooms  expenses  \
# 0 -58.508839  ...       1127.272727       1550.0    NaN    NaN       NaN
# 1 -57.964330  ...               NaN          NaN    NaN    NaN       NaN
#
#                                        properati_url  \
# 0  http://www.properati.com.ar/15bo8_venta_ph_mat...
# 1  http://www.properati.com.ar/15bob_venta_depart...
#
#                                          description  \
# 0  2 AMBIENTES TIPO CASA PLANTA BAJA POR PASILLO,...
# 1  Venta de departamento en décimo piso al frente...
#
#                                                title  \
# 0                 2 AMB TIPO CASA SIN EXPENSAS EN PB
# 1  VENTA Depto 2 dorm. a estrenar 7 e/ 36 y 37   ...
#
#                                      image_thumbnail     id
# 0  https://thumbs4.properati.com/8/BluUYiHJLhgIIK...  15bo8
# 1  https://thumbs4.properati.com/7/ikpVBu2ztHA7jv...  15bob
#
# [2 rows x 26 columns]

# %%
df.shape
# Out:
# (121220, 26)

# %% [markdown]
# # MISSING DATA

# %%
# vemos el total de nulos del dataset
df.isna().sum()[df.isna().sum()>0]
# Out:
# place_name                        23
# geonames_id                    18717
# lat-lon                        51550
# lat                            51550
# lon                            51550
# price                          20410
# currency                       20411
# price_aprox_local_currency     20410
# price_aprox_usd                20410
# surface_total_in_m2            39328
# surface_covered_in_m2          19907
# price_usd_per_m2               52603
# price_per_m2                   33562
# floor                         113321
# rooms                          73830
# expenses                      106958
# description                        2
# image_thumbnail                 3112
# dtype: int64

# %% [markdown]
# ### MISSING DATA AMBIENTES

# %%
# vemos el total de nulos del dataset en el campo 'rooms'. Son 73830 valores faltantes en total
df.isna().sum()[df.isna().sum()>0][['rooms']]
# Out:
# rooms    73830
# dtype: int64

# %%
df.rooms.unique()
# Out:
# array([nan,  1.,  4.,  3.,  2.,  6.,  5., 10.,  7.,  9.,  8., 17., 22.,
#        15., 12., 11., 14., 16., 20., 13., 25., 19., 30., 18., 32., 24.,
#        31., 21., 29., 27., 23., 28.])

# %% [markdown]
# # Ambientes

# %% [markdown]
# ### Primero tratamos de extraer información de la columna 'title' del dataset original

# %%
# creamos una copia del dataset original que solo tenga la columna 'title'
room2 = df[['title']].copy()
room2.head()
# Out:
#                                                title
# 0                 2 AMB TIPO CASA SIN EXPENSAS EN PB
# 1  VENTA Depto 2 dorm. a estrenar 7 e/ 36 y 37   ...
# 2           2 AMB 3ER PISO CON ASCENSOR APTO CREDITO
# 3                       PH 3 amb. cfte. reciclado
# 4  DEPTO 2 AMB AL CONTRAFRENTE ZONA CENTRO/PLAZA ...

# %%
# renombramos la columna 'title' como 'titulo' para que no se confunda con la del dataset original
room2.columns=['titulo']
room2.head()
# Out:
#                                               titulo
# 0                 2 AMB TIPO CASA SIN EXPENSAS EN PB
# 1  VENTA Depto 2 dorm. a estrenar 7 e/ 36 y 37   ...
# 2           2 AMB 3ER PISO CON ASCENSOR APTO CREDITO
# 3                       PH 3 amb. cfte. reciclado
# 4  DEPTO 2 AMB AL CONTRAFRENTE ZONA CENTRO/PLAZA ...

# %%
#le aplicamos la función unidecode a la columna 'titulo' para dejar el formato en minúscula y sin tildes
room2['titulo']=room2.loc[:,'titulo'].astype(str).apply(unidecode.unidecode).str.lower()
room2.head()
# Out:
#                                               titulo
# 0                 2 amb tipo casa sin expensas en pb
# 1  venta depto 2 dorm. a estrenar 7 e/ 36 y 37   ...
# 2           2 amb 3er piso con ascensor apto credito
# 3                       ph 3 amb. cfte. reciclado
# 4  depto 2 amb al contrafrente zona centro/plaza ...

# %%
#aplicamos una regex para capturar en la columna 'titulo' aquellas líneas que contengan una ref. al nro. de ambientes
#al aplicarla fx 'extract' a los dos grupos de captura devuelve los resultados en un nuevo dataframe de dos columnas
cant_amb = room2["titulo"].str.extract("(\d+)\s(amb.)")
cant_amb.head()
# Out:
#      0     1
# 0    2  amb
# 1  NaN   NaN
# 2    2  amb
# 3    3  amb.
# 4    2  amb

# %%
#unimos el df anterior al df copia del original con la fx concat
room2 = pd.concat([room2, cant_amb], axis=1)
room2.head()
# Out:
#                                               titulo    0     1
# 0                 2 amb tipo casa sin expensas en pb    2  amb
# 1  venta depto 2 dorm. a estrenar 7 e/ 36 y 37   ...  NaN   NaN
# 2           2 amb 3er piso con ascensor apto credito    2  amb
# 3                       ph 3 amb. cfte. reciclado       3  amb.
# 4  depto 2 amb al contrafrente zona centro/plaza ...    2  amb

# %%
#renombramos las nuevas columnas para quitarnos de encima los nombres '0' y '1' que se llamaban por default 
room2.columns=['titulo', 'nro_amb', 'txt_amb']

# %%
# vemos el total de nulos del dataset room2 de las nuevas columnas 'nro_amb' y 'txt_amb'
room2.isna().sum()[room2.isna().sum()>0]
# Out:
# nro_amb    100330
# txt_amb    100330
# dtype: int64

# %%
# vemos qué tipo de objeto es cada valor de la columna 'nro_amb'. Son str y float.
type(room2.nro_amb.iloc[9999])
# Out:
# str

# %%
#Corremos una fx unique para ver cuáles son valores que se levantaron. 
# Hay valores atípicos a revisar. Por ej: 9', '8', '15', '10', '11', '4000', '360', '12', '14'
# Es probable que no sean ambientes.
room2.nro_amb.unique()
# Out:
# array(['2', nan, '3', '4', '6', '1', '5', '7', '9', '8', '15', '10', '11',
#        '4000', '360', '12', '14'], dtype=object)

# %%
# repetimos el procedimiento anterior para obtener del título aquellas líneas que contengan una ref. al nro. de dormitorios
cant_dorm = room2["titulo"].str.extract("(\d+)\s(dorm.)")
cant_dorm.head()
# Out:
#      0      1
# 0  NaN    NaN
# 1    2  dorm.
# 2  NaN    NaN
# 3  NaN    NaN
# 4  NaN    NaN

# %%
#unimos el df anterior al df copia del original con la fx concat
room2 = pd.concat([room2, cant_dorm], axis=1)
room2.head()
# Out:
#                                               titulo nro_amb txt_amb    0  \
# 0                 2 amb tipo casa sin expensas en pb       2    amb   NaN
# 1  venta depto 2 dorm. a estrenar 7 e/ 36 y 37   ...     NaN     NaN    2
# 2           2 amb 3er piso con ascensor apto credito       2    amb   NaN
# 3                       ph 3 amb. cfte. reciclado          3    amb.  NaN
# 4  depto 2 amb al contrafrente zona centro/plaza ...       2    amb   NaN
#
#        1
# 0    NaN
# 1  dorm.
# 2    NaN
# 3    NaN
# 4    NaN

# %%
#renombramos las nuevas columnas para quitarnos de encima los nombres '0' y '1' que se llamaban por default 
room2.columns=['titulo', 'nro_amb', 'txt_amb', 'nro_dorm', 'txt_dorm']

# %%
# vemos qué tipo de objeto es cada valor de la columna 'nro_dorm'. Son str y float.
type(room2.nro_dorm.iloc[1])
# Out:
# str

# %%
#Corremos una fx unique para ver cuáles son valores que se levantaron. 
# Hay valores atípicos a revisar. Por ej: '7', '6', '10', '9'
# Es probable que no sean ambientes.
room2.nro_dorm.unique()
# Out:
# array([nan, '2', '5', '1', '3', '4', '7', '6', '10', '9'], dtype=object)

# %%
# vemos el total de nulos del dataset room2. Hay menos referencias a dormitorios que a ambientes.
room2.isna().sum()[room2.isna().sum()>0]
# Out:
# nro_amb     100330
# txt_amb     100330
# nro_dorm    114056
# txt_dorm    114056
# dtype: int64

# %%
# repetimos el procedimiento anterior para obtener del título aquellas líneas que contengan una ref. al nro. de habitaciones
cant_hab = room2["titulo"].str.extract("(\d+)\s(habitac...)")
cant_hab
# Out:
#           0    1
# 0       NaN  NaN
# 1       NaN  NaN
# 2       NaN  NaN
# 3       NaN  NaN
# 4       NaN  NaN
# ...     ...  ...
# 121215  NaN  NaN
# 121216  NaN  NaN
# 121217  NaN  NaN
# 121218  NaN  NaN
# 121219  NaN  NaN
#
# [121220 rows x 2 columns]

# %%
#unimos el df anterior al df copia del original con la fx concat
room2 = pd.concat([room2, cant_hab], axis=1)
room2.head()
# Out:
#                                               titulo nro_amb txt_amb nro_dorm  \
# 0                 2 amb tipo casa sin expensas en pb       2    amb       NaN
# 1  venta depto 2 dorm. a estrenar 7 e/ 36 y 37   ...     NaN     NaN        2
# 2           2 amb 3er piso con ascensor apto credito       2    amb       NaN
# 3                       ph 3 amb. cfte. reciclado          3    amb.      NaN
# 4  depto 2 amb al contrafrente zona centro/plaza ...       2    amb       NaN
#
#   txt_dorm    0    1
# 0      NaN  NaN  NaN
# 1    dorm.  NaN  NaN
# 2      NaN  NaN  NaN
# 3      NaN  NaN  NaN
# 4      NaN  NaN  NaN

# %%
#renombramos nuevamente las nuevas columnas para quitarnos de encima los nombres '0' y '1' que se llamaban por default 
room2.columns=['titulo', 'nro_amb', 'txt_amb', 'nro_dorm', 'txt_dorm', 'nro_hab', 'txt_hab']
room2.head()
# Out:
#                                               titulo nro_amb txt_amb nro_dorm  \
# 0                 2 amb tipo casa sin expensas en pb       2    amb       NaN
# 1  venta depto 2 dorm. a estrenar 7 e/ 36 y 37   ...     NaN     NaN        2
# 2           2 amb 3er piso con ascensor apto credito       2    amb       NaN
# 3                       ph 3 amb. cfte. reciclado          3    amb.      NaN
# 4  depto 2 amb al contrafrente zona centro/plaza ...       2    amb       NaN
#
#   txt_dorm nro_hab txt_hab
# 0      NaN     NaN     NaN
# 1    dorm.     NaN     NaN
# 2      NaN     NaN     NaN
# 3      NaN     NaN     NaN
# 4      NaN     NaN     NaN

# %%
# vemos qué tipo de objeto es cada valor de la columna 'nro_amb'. Son str y float.
type(room2.nro_hab.iloc[10])
# Out:
# float

# %%
#Corremos una fx unique para ver cuáles son valores que se levantaron. 
# Hay valores atípicos a revisar. Por ej: '14', '20', '9', '16', '21', '27', '11', '10'
# Es probable que no sean ambientes.
room2.nro_hab.unique()
# Out:
# array([nan, '2', '1', '8', '3', '4', '14', '20', '9', '5', '16', '21',
#        '27', '11', '10'], dtype=object)

# %%
# vemos el total de nulos del dataset room2. Las referencias a las habitaciones son menos que a las de dormitorios
room2.isna().sum()[room2.isna().sum()>0]
# Out:
# nro_amb     100330
# txt_amb     100330
# nro_dorm    114056
# txt_dorm    114056
# nro_hab     121150
# txt_hab     121150
# dtype: int64

# %%
#Rellenamos todos los NaN con ''
room2.nro_amb.fillna("",inplace=True)
room2.txt_amb.fillna("",inplace=True)
room2.nro_dorm.fillna("",inplace=True)
room2.txt_dorm.fillna("",inplace=True)
room2.nro_hab.fillna("",inplace=True)
room2.txt_hab.fillna("",inplace=True)
room2.head()
# Out:
#                                               titulo nro_amb txt_amb nro_dorm  \
# 0                 2 amb tipo casa sin expensas en pb       2    amb
# 1  venta depto 2 dorm. a estrenar 7 e/ 36 y 37   ...                        2
# 2           2 amb 3er piso con ascensor apto credito       2    amb
# 3                       ph 3 amb. cfte. reciclado          3    amb.
# 4  depto 2 amb al contrafrente zona centro/plaza ...       2    amb
#
#   txt_dorm nro_hab txt_hab
# 0
# 1    dorm.
# 2
# 3
# 4

# %%
#verifico que no haya NaN en las columnas y que haya valores vacíos en su lugar
room2.nro_amb.unique()
# Out:
# array(['2', '', '3', '4', '6', '1', '5', '7', '9', '8', '15', '10', '11',
#        '4000', '360', '12', '14'], dtype=object)

# %%
type(room2.nro_amb[1])
# Out:
# str

# %%
#hacemos un conteo real de nulos después de reemplazar texto por números. 
# Tenemos 94544 nulos.
len(room2.loc[(room2.nro_amb=="")&(room2.nro_dorm=="")&(room2.nro_hab=="")])
# Out:
# 93189

# %%
#creamos una nueva columna que es la suma de ambientes, dormitorios y habitaciones.
#Gran supuesto: si hay ref a cantidad de ambientes cubiertos, no la hay de dormitorios o habitaciones.
#por lo tanto 'ambientes' reúne la cantidad de ambientes que pudimos extraer de 'titulo'
room2['ambientes_tit'] = room2['nro_amb'] + room2['nro_dorm'] + room2['nro_hab']
room2.head(15)
# Out:
#                                                titulo nro_amb txt_amb  \
# 0                  2 amb tipo casa sin expensas en pb       2    amb
# 1   venta depto 2 dorm. a estrenar 7 e/ 36 y 37   ...
# 2            2 amb 3er piso con ascensor apto credito       2    amb
# 3                        ph 3 amb. cfte. reciclado          3    amb.
# 4   depto 2 amb al contrafrente zona centro/plaza ...       2    amb
# 5   casa barrio 338. sobre calle 3 de caballeria, ...
# 6   muy buen ph al frente dos dormitorios , patio,...
# 7   jose hernandez 1400 monoambiente  estrenar cat...
# 8   jose hernandez   1400 dos ambientes estrenar ,...
# 9          white 7637 - 2 dormitorios con patio
# 10  casa sin terminar en falda de canete.         ...
# 11                                            chalet
# 12  excelente departamento 2 ambientes contrafrent...       2    ambi
# 13                                    vitraux palermo
# 14                                    vitraux palermo
#
#    nro_dorm txt_dorm nro_hab txt_hab ambientes_tit
# 0                                                2
# 1         2    dorm.                             2
# 2                                                2
# 3                                                3
# 4                                                2
# 5
# 6
# 7
# 8
# 9         2    dormi                             2
# 10
# 11
# 12                                               2
# 13
# 14

# %%
#vemos que son todos str
type(room2['ambientes_tit'][1000])
# Out:
# str

# %%
room2.ambientes_tit.unique()
# Out:
# array(['2', '3', '', '4', '5', '6', '1', '43', '32', '52', '7', '9', '8',
#        '53', '15', '64', '54', '21', '14', '22', '10', '11', '42', '20',
#        '23', '24', '65', '13', '4000', '16', '27', '3601', '12', '84'],
#       dtype=object)

# %%
#reemplazo los str que son valores atípicos
room2.ambientes_tit=room2.ambientes_tit.str.replace('43','').replace('32','').replace('52','').replace('53','').replace('64','').replace('54','').replace('21','').replace('42','').replace('20','').replace('23','').replace('24','').replace('22','').replace('65','').replace('4000','').replace('27','').replace('3601','').replace('84','')

# %%
room2.ambientes_tit.unique()
# Out:
# array(['2', '3', '', '4', '5', '6', '1', '7', '9', '8', '15', '14', '10',
#        '11', '13', '16', '12'], dtype=object)

# %%
len(room2.loc[(room2.ambientes_tit=="")])
# Out:
# 93285

# %%
room2.dtypes
# Out:
# titulo           object
# nro_amb          object
# txt_amb          object
# nro_dorm         object
# txt_dorm         object
# nro_hab          object
# txt_hab          object
# ambientes_tit    object
# dtype: object

# %%
#concatenamos el room2 al df original
df = pd.concat([df, room2], axis=1)
df.head()
# Out:
#   operation property_type place_name  \
# 0      sell            PH  Mataderos
# 1      sell     apartment   La Plata
# 2      sell     apartment  Mataderos
# 3      sell            PH    Liniers
# 4      sell     apartment     Centro
#
#                              place_with_parent_names country_name  \
# 0              |Argentina|Capital Federal|Mataderos|    Argentina
# 1        |Argentina|Bs.As. G.B.A. Zona Sur|La Plata|    Argentina
# 2              |Argentina|Capital Federal|Mataderos|    Argentina
# 3                |Argentina|Capital Federal|Liniers|    Argentina
# 4  |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
#
#                      state_name  geonames_id                  lat-lon  \
# 0               Capital Federal    3430787.0  -34.6618237,-58.5088387
# 1        Bs.As. G.B.A. Zona Sur    3432039.0  -34.9038831,-57.9643295
# 2               Capital Federal    3430787.0  -34.6522615,-58.5229825
# 3               Capital Federal    3431333.0  -34.6477969,-58.5164244
# 4  Buenos Aires Costa Atlántica    3435548.0  -38.0026256,-57.5494468
#
#          lat        lon  ...  \
# 0 -34.661824 -58.508839  ...
# 1 -34.903883 -57.964330  ...
# 2 -34.652262 -58.522982  ...
# 3 -34.647797 -58.516424  ...
# 4 -38.002626 -57.549447  ...
#
#                                      image_thumbnail     id  \
# 0  https://thumbs4.properati.com/8/BluUYiHJLhgIIK...  15bo8
# 1  https://thumbs4.properati.com/7/ikpVBu2ztHA7jv...  15bob
# 2  https://thumbs4.properati.com/5/SXKr34F_IwG3W_...  15bod
# 3  https://thumbs4.properati.com/3/DgIfX-85Mog5SP...  15boh
# 4  https://thumbs4.properati.com/5/xrRqlNcSI_vs-f...  15bok
#
#                                               titulo  nro_amb  txt_amb  \
# 0                 2 amb tipo casa sin expensas en pb        2     amb
# 1  venta depto 2 dorm. a estrenar 7 e/ 36 y 37   ...
# 2           2 amb 3er piso con ascensor apto credito        2     amb
# 3                       ph 3 amb. cfte. reciclado           3     amb.
# 4  depto 2 amb al contrafrente zona centro/plaza ...        2     amb
#
#    nro_dorm  txt_dorm  nro_hab  txt_hab  ambientes_tit
# 0                                                    2
# 1         2     dorm.                                2
# 2                                                    2
# 3                                                    3
# 4                                                    2
#
# [5 rows x 34 columns]

# %%
#quitamos las columnas que no nos interesan
df=df.drop (["titulo","nro_amb","txt_amb","nro_dorm","txt_dorm", "nro_hab","txt_hab"], axis=1)
df.head()
# Out:
#   operation property_type place_name  \
# 0      sell            PH  Mataderos
# 1      sell     apartment   La Plata
# 2      sell     apartment  Mataderos
# 3      sell            PH    Liniers
# 4      sell     apartment     Centro
#
#                              place_with_parent_names country_name  \
# 0              |Argentina|Capital Federal|Mataderos|    Argentina
# 1        |Argentina|Bs.As. G.B.A. Zona Sur|La Plata|    Argentina
# 2              |Argentina|Capital Federal|Mataderos|    Argentina
# 3                |Argentina|Capital Federal|Liniers|    Argentina
# 4  |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
#
#                      state_name  geonames_id                  lat-lon  \
# 0               Capital Federal    3430787.0  -34.6618237,-58.5088387
# 1        Bs.As. G.B.A. Zona Sur    3432039.0  -34.9038831,-57.9643295
# 2               Capital Federal    3430787.0  -34.6522615,-58.5229825
# 3               Capital Federal    3431333.0  -34.6477969,-58.5164244
# 4  Buenos Aires Costa Atlántica    3435548.0  -38.0026256,-57.5494468
#
#          lat        lon  ...  price_per_m2 floor  rooms  expenses  \
# 0 -34.661824 -58.508839  ...   1550.000000   NaN    NaN       NaN
# 1 -34.903883 -57.964330  ...           NaN   NaN    NaN       NaN
# 2 -34.652262 -58.522982  ...   1309.090909   NaN    NaN       NaN
# 3 -34.647797 -58.516424  ...           NaN   NaN    NaN       NaN
# 4 -38.002626 -57.549447  ...   1828.571429   NaN    NaN       NaN
#
#                                        properati_url  \
# 0  http://www.properati.com.ar/15bo8_venta_ph_mat...
# 1  http://www.properati.com.ar/15bob_venta_depart...
# 2  http://www.properati.com.ar/15bod_venta_depart...
# 3  http://www.properati.com.ar/15boh_venta_ph_lin...
# 4  http://www.properati.com.ar/15bok_venta_depart...
#
#                                          description  \
# 0  2 AMBIENTES TIPO CASA PLANTA BAJA POR PASILLO,...
# 1  Venta de departamento en décimo piso al frente...
# 2  2 AMBIENTES 3ER PISO LATERAL LIVING COMEDOR AM...
# 3  PH 3 ambientes con patio. Hay 3 deptos en lote...
# 4  DEPARTAMENTO CON FANTÁSTICA ILUMINACIÓN NATURA...
#
#                                                title  \
# 0                 2 AMB TIPO CASA SIN EXPENSAS EN PB
# 1  VENTA Depto 2 dorm. a estrenar 7 e/ 36 y 37   ...
# 2           2 AMB 3ER PISO CON ASCENSOR APTO CREDITO
# 3                       PH 3 amb. cfte. reciclado
# 4  DEPTO 2 AMB AL CONTRAFRENTE ZONA CENTRO/PLAZA ...
#
#                                      image_thumbnail     id  ambientes_tit
# 0  https://thumbs4.properati.com/8/BluUYiHJLhgIIK...  15bo8              2
# 1  https://thumbs4.properati.com/7/ikpVBu2ztHA7jv...  15bob              2
# 2  https://thumbs4.properati.com/5/SXKr34F_IwG3W_...  15bod              2
# 3  https://thumbs4.properati.com/3/DgIfX-85Mog5SP...  15boh              3
# 4  https://thumbs4.properati.com/5/xrRqlNcSI_vs-f...  15bok              2
#
# [5 rows x 27 columns]

# %%
#chequeamos que la cantidad de registros en la col 'rooms' no es igual a la cant de registros en 'ambientes'
print('¿Cantidad total calculada y original son iguales? {}'\
       .format(df.ambientes_tit.equals(df.rooms)))
# Out:
# ¿Cantidad total calculada y original son iguales? False

# %%
#creamos una máscara booleana que nos dice 'True' los que no son iguales y 'False' los que coinciden
(df.ambientes_tit != df.rooms)
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 121215    True
# 121216    True
# 121217    True
# 121218    True
# 121219    True
# Length: 121220, dtype: bool

# %% [markdown]
# ### En segundo lugar tratamos de extraer cantidad de ambientes de la columna "description"

# %%
#copiamos la columna 'description' a un dataframe distinto de una columna
room3 = df[['description']].copy()
room3.head()
# Out:
#                                          description
# 0  2 AMBIENTES TIPO CASA PLANTA BAJA POR PASILLO,...
# 1  Venta de departamento en décimo piso al frente...
# 2  2 AMBIENTES 3ER PISO LATERAL LIVING COMEDOR AM...
# 3  PH 3 ambientes con patio. Hay 3 deptos en lote...
# 4  DEPARTAMENTO CON FANTÁSTICA ILUMINACIÓN NATURA...

# %%
# renombramos la columna 'descrption' como 'descrip' para que no se confunda con la del dataset original
room3.columns=['descrip']
room3.head()
# Out:
#                                              descrip
# 0  2 AMBIENTES TIPO CASA PLANTA BAJA POR PASILLO,...
# 1  Venta de departamento en décimo piso al frente...
# 2  2 AMBIENTES 3ER PISO LATERAL LIVING COMEDOR AM...
# 3  PH 3 ambientes con patio. Hay 3 deptos en lote...
# 4  DEPARTAMENTO CON FANTÁSTICA ILUMINACIÓN NATURA...

# %%
#le aplicamos la función unidecode a la columna 'descrip' para dejar el formato en minúscula y sin tildes
room3['descrip']=room3.loc[:,'descrip'].astype(str).apply(unidecode.unidecode).str.lower()
room3.head()
# Out:
#                                              descrip
# 0  2 ambientes tipo casa planta baja por pasillo,...
# 1  venta de departamento en decimo piso al frente...
# 2  2 ambientes 3er piso lateral living comedor am...
# 3  ph 3 ambientes con patio. hay 3 deptos en lote...
# 4  departamento con fantastica iluminacion natura...

# %%
#aplicamos una regex para capturar en la columna 'titulo' aquellas líneas que contengan una ref. al nro. de ambientes
#al aplicarla fx 'extract' a los dos grupos de captura devuelve los resultados en un nuevo dataframe de dos columnas
cant_amb_descrip = room3["descrip"].str.extract("(\d+)\s(amb.)")
cant_amb_descrip.head()
# Out:
#      0     1
# 0    2  ambi
# 1  NaN   NaN
# 2    2  ambi
# 3    3  ambi
# 4  NaN   NaN

# %%
#unimos el df anterior al df copia del original con la fx concat
room3 = pd.concat([room3, cant_amb_descrip], axis=1)
room3.head()
# Out:
#                                              descrip    0     1
# 0  2 ambientes tipo casa planta baja por pasillo,...    2  ambi
# 1  venta de departamento en decimo piso al frente...  NaN   NaN
# 2  2 ambientes 3er piso lateral living comedor am...    2  ambi
# 3  ph 3 ambientes con patio. hay 3 deptos en lote...    3  ambi
# 4  departamento con fantastica iluminacion natura...  NaN   NaN

# %%
#renombramos las nuevas columnas para quitarnos de encima los nombres '0' y '1' que se llamaban por default 
room3.columns=['descrip', 'nro_amb', 'txt_amb']
room3.head()
# Out:
#                                              descrip nro_amb txt_amb
# 0  2 ambientes tipo casa planta baja por pasillo,...       2    ambi
# 1  venta de departamento en decimo piso al frente...     NaN     NaN
# 2  2 ambientes 3er piso lateral living comedor am...       2    ambi
# 3  ph 3 ambientes con patio. hay 3 deptos en lote...       3    ambi
# 4  departamento con fantastica iluminacion natura...     NaN     NaN

# %%
# vemos el total de nulos del dataset room2 de las nuevas columnas 'nro_amb' y 'txt_amb'
room3.isna().sum()[room3.isna().sum()>0]
# Out:
# nro_amb    83681
# txt_amb    83681
# dtype: int64

# %%
# vemos qué tipo de objeto es cada valor de la columna 'nro_amb'. Son str y float.
type(room3.nro_amb.iloc[15])
# Out:
# float

# %%
#Corremos una fx unique para ver cuáles son valores que se levantaron. 
# Hay valores atípicos a revisar.
# Es probable que no sean ambientes.
room3.nro_amb.unique()
# Out:
# array(['2', nan, '3', '1', '4', '5', '7', '6', '415', '50', '042', '8',
#        '25', '9', '23', '2017', '103', '297', '42026', '072', '902', '18',
#        '000', '11', '944', '22', '0002', '153', '472', '281', '442', '24',
#        '22330489662', '10', '12', '20173', '9502', '1200', '33', '772',
#        '652', '004', '653', '983', '42025', '42004', '42028', '151',
#        '42046', '42049', '412', '42015', '42021', '172', '28612', '20174',
#        '547', '693', '622', '733', '14', '183', '793', '00', '253', '006',
#        '913', '20171', '20172', '853', '173', '162', '123', '0', '202',
#        '192', '113', '17', '90', '0001', '2004', '20', '822', '562',
#        '42054', '293', '65', '84', '872', '164', '312', '42024', '102'],
#       dtype=object)

# %%
# repetimos el procedimiento anterior para obtener del título aquellas líneas que contengan una ref. al nro. de dormitorios
cant_dorm_descrip = room3["descrip"].str.extract("(\d+)\s(dorm.)")
cant_dorm_descrip.head()
# Out:
#      0      1
# 0  NaN    NaN
# 1  NaN    NaN
# 2  NaN    NaN
# 3  NaN    NaN
# 4    1  dormi

# %%
#unimos el df anterior al df copia del original con la fx concat
room3 = pd.concat([room3, cant_dorm_descrip], axis=1)
room3.head()
# Out:
#                                              descrip nro_amb txt_amb    0  \
# 0  2 ambientes tipo casa planta baja por pasillo,...       2    ambi  NaN
# 1  venta de departamento en decimo piso al frente...     NaN     NaN  NaN
# 2  2 ambientes 3er piso lateral living comedor am...       2    ambi  NaN
# 3  ph 3 ambientes con patio. hay 3 deptos en lote...       3    ambi  NaN
# 4  departamento con fantastica iluminacion natura...     NaN     NaN    1
#
#        1
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4  dormi

# %%
#renombramos nuevamente las nuevas columnas para quitarnos de encima los nombres '0' y '1' que se llamaban por default 
room3.columns=['descrip', 'nro_amb', 'txt_amb', 'nro_dorm', 'txt_dorm']
room3.head()
# Out:
#                                              descrip nro_amb txt_amb nro_dorm  \
# 0  2 ambientes tipo casa planta baja por pasillo,...       2    ambi      NaN
# 1  venta de departamento en decimo piso al frente...     NaN     NaN      NaN
# 2  2 ambientes 3er piso lateral living comedor am...       2    ambi      NaN
# 3  ph 3 ambientes con patio. hay 3 deptos en lote...       3    ambi      NaN
# 4  departamento con fantastica iluminacion natura...     NaN     NaN        1
#
#   txt_dorm
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4    dormi

# %%
# vemos qué tipo de objeto es cada valor de la columna 'nro_dorm'. Son str y float.
type(room3.nro_dorm.iloc[0])
# Out:
# float

# %%
# vemos el total de nulos del dataset room2. Hay más referencias a dormitorios que a ambientes.
room3.isna().sum()[room3.isna().sum()>0]
# Out:
# nro_amb     83681
# txt_amb     83681
# nro_dorm    80423
# txt_dorm    80423
# dtype: int64

# %%
# repetimos el procedimiento anterior para obtener del título aquellas líneas que contengan una ref. al nro. de habitaciones
cant_hab_descrip = room3["descrip"].str.extract("(\d+)\s(hab...)")
cant_hab_descrip.head()
# Out:
#      0    1
# 0  NaN  NaN
# 1  NaN  NaN
# 2  NaN  NaN
# 3  NaN  NaN
# 4  NaN  NaN

# %%
#unimos el df anterior al df copia del original con la fx concat
room3 = pd.concat([room3, cant_hab_descrip], axis=1)
room3.head()
# Out:
#                                              descrip nro_amb txt_amb nro_dorm  \
# 0  2 ambientes tipo casa planta baja por pasillo,...       2    ambi      NaN
# 1  venta de departamento en decimo piso al frente...     NaN     NaN      NaN
# 2  2 ambientes 3er piso lateral living comedor am...       2    ambi      NaN
# 3  ph 3 ambientes con patio. hay 3 deptos en lote...       3    ambi      NaN
# 4  departamento con fantastica iluminacion natura...     NaN     NaN        1
#
#   txt_dorm    0    1
# 0      NaN  NaN  NaN
# 1      NaN  NaN  NaN
# 2      NaN  NaN  NaN
# 3      NaN  NaN  NaN
# 4    dormi  NaN  NaN

# %%
#renombramos nuevamente las nuevas columnas para quitarnos de encima los nombres '0' y '1' que se llamaban por default 
room3.columns=['descrip', 'nro_amb', 'txt_amb', 'nro_dorm', 'txt_dorm', 'nro_hab', 'txt_hab']
room3.head()
# Out:
#                                              descrip nro_amb txt_amb nro_dorm  \
# 0  2 ambientes tipo casa planta baja por pasillo,...       2    ambi      NaN
# 1  venta de departamento en decimo piso al frente...     NaN     NaN      NaN
# 2  2 ambientes 3er piso lateral living comedor am...       2    ambi      NaN
# 3  ph 3 ambientes con patio. hay 3 deptos en lote...       3    ambi      NaN
# 4  departamento con fantastica iluminacion natura...     NaN     NaN        1
#
#   txt_dorm nro_hab txt_hab
# 0      NaN     NaN     NaN
# 1      NaN     NaN     NaN
# 2      NaN     NaN     NaN
# 3      NaN     NaN     NaN
# 4    dormi     NaN     NaN

# %%
# vemos qué tipo de objeto es cada valor de la columna 'nro_amb'. Son str y float.
type(room3.nro_hab.iloc[10])
# Out:
# float

# %%
#Corremos una fx unique para ver cuáles son valores que se levantaron. 
# Hay valores atípicos a revisar. Por ej: '14', '20', '9', '16', '21', '27', '11', '10'
# Es probable que no sean ambientes.
room3.nro_hab.unique()
# Out:
# array([nan, '2', '3', '2000', '4', '5', '30', '1', '9', '55', '6', '8',
#        '16', '290', '7', '10', '13', '400', '800', '14', '54', '1500',
#        '21', '57', '24', '12', '140', '71', '72', '130', '425', '90',
#        '120', '200', '11', '150', '600', '27', '20', '170', '51', '160',
#        '40', '047', '80', '17', '103', '450', '02', '102', '66', '18',
#        '16002', '210', '000', '22', '124', '25', '29', '23', '52', '33',
#        '15', '32', '50', '1000', '56', '500', '36'], dtype=object)

# %%
# vemos el total de nulos del dataset room2. Las referencias a las habitaciones son menos que a las de dormitorios
room3.isna().sum()[room3.isna().sum()>0]
# Out:
# nro_amb      83681
# txt_amb      83681
# nro_dorm     80423
# txt_dorm     80423
# nro_hab     118161
# txt_hab     118161
# dtype: int64

# %%
#Rellenamos todos los NaN con ''
room3.nro_amb.fillna("",inplace=True)
room3.txt_amb.fillna("",inplace=True)
room3.nro_dorm.fillna("",inplace=True)
room3.txt_dorm.fillna("",inplace=True)
room3.nro_hab.fillna("",inplace=True)
room3.txt_hab.fillna("",inplace=True)
room3.head()
# Out:
#                                              descrip nro_amb txt_amb nro_dorm  \
# 0  2 ambientes tipo casa planta baja por pasillo,...       2    ambi
# 1  venta de departamento en decimo piso al frente...
# 2  2 ambientes 3er piso lateral living comedor am...       2    ambi
# 3  ph 3 ambientes con patio. hay 3 deptos en lote...       3    ambi
# 4  departamento con fantastica iluminacion natura...                        1
#
#   txt_dorm nro_hab txt_hab
# 0
# 1
# 2
# 3
# 4    dormi

# %%
#hacemos un conteo real de nulos después de reemplazar texto por números. 
# Tenemos 50507 nulos.
len(room3.loc[(room3.nro_amb=="")&(room3.nro_dorm=="")&(room3.nro_hab=="")])
# Out:
# 50492

# %%
#creamos una nueva columna que es la suma de ambientes, dormitorios y habitaciones.
#Gran supuesto: si hay ref a cantidad de ambientes cubiertos, no la hay de dormitorios o habitaciones.
#por lo tanto 'ambientes' reúne la cantidad de ambientes que pudimos extraer de 'titulo'
room3['ambientes_descrip'] = room3['nro_amb'] + room3['nro_dorm'] + room3['nro_hab']
room3.head(50)
# Out:
#                                               descrip nro_amb txt_amb  \
# 0   2 ambientes tipo casa planta baja por pasillo,...       2    ambi
# 1   venta de departamento en decimo piso al frente...
# 2   2 ambientes 3er piso lateral living comedor am...       2    ambi
# 3   ph 3 ambientes con patio. hay 3 deptos en lote...       3    ambi
# 4   departamento con fantastica iluminacion natura...
# 5   casa en el perimetro del barrio 338, ubicada e...
# 6   muy buen ph al frente con entrada independient...
# 7   excelente monoambiente a estrenar amplio super...
# 8   excelente dos ambientes  estrenar amplio super...
# 9   mednoza al 7600a una cuadra de calle mendozawh...
# 10  hermosa casa sin terminar de 3 dormitorios, ba...
# 11  entrada de coche, jardin, living en desnivel, ...       1    ambi
# 12  excelente departamento 2 ambientes contrafrent...       2    ambi
# 13   torre i mondrian. 3 ambientes con terraza y d...       3    ambi
# 14  torre ii dali. ambiente unico divisible.vitrau...
# 15  ultima unidad disponiblehaus boulevard: metros...
# 16  ventas mataderos al frente duplex 4 amb.- plan...       4    amb.
# 17  excelente 3 ambientes en un 6 piso y con terra...       3    ambi
# 18  casa sobre lote al golf en barrio san isidro l...
# 19  excelente semipiso al contra frente en bulnes ...
# 20  consta de: comedor-cocina, cuatro dormitorios ...
# 21  excelente zona, multiples medios de transporte...
# 22  edificada en 2 plantas. pb. amplio living con ...
# 23  hermoso departamento, ubicado en la calle almi...
# 24  exclusivo  departamento de excelente categoria...       4    ambi
# 25  exclusivo  departamento de excelente categoria...       4    ambi
# 26  casa en venta en complejo villanueva barrio sa...
# 27  estancias propone vivir rodeados de naturaleza...
# 28  exclusivo  departamento de excelente categoria...       4    ambi
# 29  departamento muy luminoso con todos sus ambien...
# 30  muy linda casa , toda en planta baja, doble pa...
# 31  muy buena casa tipo americana de 3 ambientes c...       3    ambi
# 32  en venta, departamento ubicado en barrio pueyr...
# 33  excelente 3 ambientes en un 6 piso en esquina ...       3    ambi
# 34  amplio ph de 5 dormitorios, ubicado a 3 cuadra...
# 35  hermoso departamento de cuatro ambientes, refa...
# 36  casa en pilar centro ,a pocas cuadras de la pl...
# 37  nuevos ingreso:-venta-villa san nicolas.presen...
# 38  espectacular loft de exclusivo diseno, 210 ms,...
# 39  casa a estrenar en barrio san eduardo , pilar ...
# 40  lindisimo departamento en venta, 3 ambientes c...       3    ambi
# 41  "arecas" es un complejo de duplex y departamen...
# 42  ubicado en planta baja, posee patio y un area ...
# 43  impecable depto, en venta con renta, pilar gar...
# 44  ideal desarrollistas:zona uca .densidad 800 ( ...
# 45  hermoso monoambiente, ideal profesional!!!apar...       3    ambi
# 46  excelente duplex, en condominio con seguridad....
# 47  estructura ecologica flotanteideal para ubicar...
# 48  piso 13, orientacion norte, disposicion al fre...
# 49  jpl. casa en el barrio san sebastian con bajad...
#
#    nro_dorm txt_dorm nro_hab txt_hab ambientes_descrip
# 0                                                    2
# 1
# 2                                                    2
# 3                                                    3
# 4         1    dormi                                 1
# 5
# 6
# 7
# 8
# 9         2    dormi                                 2
# 10        3    dormi                                 3
# 11        2    dormi                                12
# 12       30    dormi                               230
# 13                                                   3
# 14
# 15        3    dormi                                 3
# 16        3    dormi                                43
# 17                                                   3
# 18
# 19
# 20
# 21
# 22        3    dormi                                 3
# 23        1    dormi                                 1
# 24        3    dormi                                43
# 25        3    dormi                                43
# 26
# 27
# 28        3    dormi                                43
# 29
# 30        3    dormi                                 3
# 31                                                   3
# 32
# 33                                                   3
# 34        5    dormi                                 5
# 35
# 36        3    dormi                                 3
# 37
# 38
# 39        2    dormi                                 2
# 40        2    dormi                                32
# 41        3    dorm.                                 3
# 42
# 43
# 44        3    dormi                                 3
# 45                                                   3
# 46
# 47
# 48        2    dormi                                 2
# 49

# %%
#Corremos una fx unique para ver cuáles son valores que se levantaron. 
# Hay valores atípicos a revisar. Es probable que no sean ambientes.
room3.ambientes_descrip.unique()
# Out:
# array(['2', '', '3', '1', '12', '230', '43', '5', '32', '22', '4', '54',
#        '53', '74', '42000', '21', '42', '24', '23', '31', '63', '6', '44',
#        '75', '30', '51', '64', '33', '52', '35', '62', '45', '72', '8',
#        '11', '432', '4154', '503', '41', '9', '7', '322', '345', '55',
#        '103', '9504', '228', '48', '042', '84', '493', '73', '2516', '93',
#        '1290', '232', '184', '77', '10', '18', '13', '400', '340', '34',
#        '43800', '2017', '61', '380', '297', '42026', '072', '14', '65',
#        '1500', '350', '902', '183', '102', '0002', '742', '57', '622',
#        '710', '714', '7521', '944', '511', '76', '221', '60', '2140',
#        '88', '99', '278', '532', '412', '71', '1532', '87', '22130',
#        '2425', '365003', '472', '321', '002', '290', '120', '422', '722',
#        '83', '281', '612', '20', '00', '420', '442', '241', '22330489662',
#        '2200', '542', '15111', '11491', '29271', '9311', '13303', '6731',
#        '18472', '24161', '15642', '9152', '16801', '26791', '19812',
#        '21293', '24383', '11735', '5811', '21682', '613562', '691',
#        '8993', '10313', '109', '3290', '325', '20173', '9502', '1425',
#        '1200', '3201', '02', '03', '119', '772', '652', '85', '954',
#        '0043', '330', '11582', '3400', '150', '600', '610', '302', '421',
#        '631', '611', '1042', '13873', '6532', '435', '27', '440', '86',
#        '983', '320', '42025', '2170', '855', '170', '42004', '117', '25',
#        '312', '632', '251', '94', '420282', '1511', '42046', '560', '81',
#        '2160', '42049', '26', '323', '431', '842', '711', '8521', '403',
#        '514', '74316', '621', '000', '0001', '40', '00022', '047', '98',
#        '42015', '42021', '23001', '130', '17', '100', '521', '420153',
#        '385', '502', '172', '28612', '104', '201741', '5474', '6932',
#        '80', '390', '42181824', '523', '62274', '733', '212', '210',
#        '332', '7932', '37341', '13402', '50', '82', '43450', '36', '0042',
#        '113', '543', '613', '5102', '253', '006', '266', '5802', '248',
#        '6090', '14743', '913', '3302', '0', '20171', '20172', '0003',
#        '3204', '7055', '8532', '372', '92', '16002', '420212', '1732',
#        '1622', '10363', '70', '1110', '215', '123', '022', '202', '433',
#        '404', '448', '192', '420262', '565', '16', '080', '222', '342',
#        '5210', '29', '125', '2000', '1000', '124', '233', '485', '90',
#        '9014', '91', '423', '140', '20042', '5001', '141', '47', '270',
#        '211', '20191', '153', '644', '5104', '662', '5323', '315', '4000',
#        '326', '3170', '148', '15', '6003', '602', '28', '822', '562',
#        '42054', '544', '68', '3112', '5252', '311', '19754', '200',
#        '1410', '66', '05', '2932', '42028', '1333', '218', '56', '843',
#        '2500', '872', '1643', '7332', '6030', '427', '285', '3121',
#        '42024'], dtype=object)

# %%
#concatenamos el room3 al df original
df = pd.concat([df, room3], axis=1)
df.head()
# Out:
#   operation property_type place_name  \
# 0      sell            PH  Mataderos
# 1      sell     apartment   La Plata
# 2      sell     apartment  Mataderos
# 3      sell            PH    Liniers
# 4      sell     apartment     Centro
#
#                              place_with_parent_names country_name  \
# 0              |Argentina|Capital Federal|Mataderos|    Argentina
# 1        |Argentina|Bs.As. G.B.A. Zona Sur|La Plata|    Argentina
# 2              |Argentina|Capital Federal|Mataderos|    Argentina
# 3                |Argentina|Capital Federal|Liniers|    Argentina
# 4  |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
#
#                      state_name  geonames_id                  lat-lon  \
# 0               Capital Federal    3430787.0  -34.6618237,-58.5088387
# 1        Bs.As. G.B.A. Zona Sur    3432039.0  -34.9038831,-57.9643295
# 2               Capital Federal    3430787.0  -34.6522615,-58.5229825
# 3               Capital Federal    3431333.0  -34.6477969,-58.5164244
# 4  Buenos Aires Costa Atlántica    3435548.0  -38.0026256,-57.5494468
#
#          lat        lon  ...     id ambientes_tit  \
# 0 -34.661824 -58.508839  ...  15bo8             2
# 1 -34.903883 -57.964330  ...  15bob             2
# 2 -34.652262 -58.522982  ...  15bod             2
# 3 -34.647797 -58.516424  ...  15boh             3
# 4 -38.002626 -57.549447  ...  15bok             2
#
#                                              descrip  nro_amb  txt_amb  \
# 0  2 ambientes tipo casa planta baja por pasillo,...        2     ambi
# 1  venta de departamento en decimo piso al frente...
# 2  2 ambientes 3er piso lateral living comedor am...        2     ambi
# 3  ph 3 ambientes con patio. hay 3 deptos en lote...        3     ambi
# 4  departamento con fantastica iluminacion natura...
#
#    nro_dorm  txt_dorm  nro_hab  txt_hab  ambientes_descrip
# 0                                                        2
# 1
# 2                                                        2
# 3                                                        3
# 4         1     dormi                                    1
#
# [5 rows x 35 columns]

# %%
#quitamos las columnas que no nos interesan
df=df.drop (["descrip","nro_amb","txt_amb","nro_dorm","txt_dorm", "nro_hab","txt_hab"], axis=1)
df.head(12)
# Out:
#    operation property_type    place_name  \
# 0       sell            PH     Mataderos
# 1       sell     apartment      La Plata
# 2       sell     apartment     Mataderos
# 3       sell            PH       Liniers
# 4       sell     apartment        Centro
# 5       sell         house  Gualeguaychú
# 6       sell            PH         Munro
# 7       sell     apartment      Belgrano
# 8       sell     apartment      Belgrano
# 9       sell         house       Rosario
# 10      sell         house       Córdoba
# 11      sell         house    San Miguel
#
#                               place_with_parent_names country_name  \
# 0               |Argentina|Capital Federal|Mataderos|    Argentina
# 1         |Argentina|Bs.As. G.B.A. Zona Sur|La Plata|    Argentina
# 2               |Argentina|Capital Federal|Mataderos|    Argentina
# 3                 |Argentina|Capital Federal|Liniers|    Argentina
# 4   |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
# 5                 |Argentina|Entre Ríos|Gualeguaychú|    Argentina
# 6   |Argentina|Bs.As. G.B.A. Zona Norte|Vicente Ló...    Argentina
# 7                |Argentina|Capital Federal|Belgrano|    Argentina
# 8                |Argentina|Capital Federal|Belgrano|    Argentina
# 9                        |Argentina|Santa Fe|Rosario|    Argentina
# 10                        |Argentina|Córdoba|Córdoba|    Argentina
# 11    |Argentina|Bs.As. G.B.A. Zona Norte|San Miguel|    Argentina
#
#                       state_name  geonames_id                  lat-lon  \
# 0                Capital Federal    3430787.0  -34.6618237,-58.5088387
# 1         Bs.As. G.B.A. Zona Sur    3432039.0  -34.9038831,-57.9643295
# 2                Capital Federal    3430787.0  -34.6522615,-58.5229825
# 3                Capital Federal    3431333.0  -34.6477969,-58.5164244
# 4   Buenos Aires Costa Atlántica    3435548.0  -38.0026256,-57.5494468
# 5                     Entre Ríos    3433657.0   -33.0140714,-58.519828
# 6       Bs.As. G.B.A. Zona Norte    3430511.0  -34.5329567,-58.5217825
# 7                Capital Federal    3436077.0   -34.5598729,-58.443362
# 8                Capital Federal    3436077.0   -34.5598729,-58.443362
# 9                       Santa Fe    3838574.0   -32.942031,-60.7259192
# 10                       Córdoba    3860259.0  -31.4200833,-64.1887761
# 11      Bs.As. G.B.A. Zona Norte          NaN  -34.5390571,-58.7196093
#
#           lat        lon  ...  floor rooms  expenses  \
# 0  -34.661824 -58.508839  ...    NaN   NaN       NaN
# 1  -34.903883 -57.964330  ...    NaN   NaN       NaN
# 2  -34.652262 -58.522982  ...    NaN   NaN       NaN
# 3  -34.647797 -58.516424  ...    NaN   NaN       NaN
# 4  -38.002626 -57.549447  ...    NaN   NaN       NaN
# 5  -33.014071 -58.519828  ...    NaN   NaN       NaN
# 6  -34.532957 -58.521782  ...    NaN   NaN       NaN
# 7  -34.559873 -58.443362  ...    NaN   NaN       NaN
# 8  -34.559873 -58.443362  ...    NaN   NaN       NaN
# 9  -32.942031 -60.725919  ...    NaN   NaN       NaN
# 10 -31.420083 -64.188776  ...    NaN   NaN       NaN
# 11 -34.539057 -58.719609  ...    NaN   NaN       NaN
#
#                                         properati_url  \
# 0   http://www.properati.com.ar/15bo8_venta_ph_mat...
# 1   http://www.properati.com.ar/15bob_venta_depart...
# 2   http://www.properati.com.ar/15bod_venta_depart...
# 3   http://www.properati.com.ar/15boh_venta_ph_lin...
# 4   http://www.properati.com.ar/15bok_venta_depart...
# 5   http://www.properati.com.ar/15bop_venta_depart...
# 6   http://www.properati.com.ar/15bor_venta_ph_mun...
# 7   http://www.properati.com.ar/15bot_venta_depart...
# 8   http://www.properati.com.ar/15bou_venta_depart...
# 9   http://www.properati.com.ar/15box_venta_casa_r...
# 10  http://www.properati.com.ar/15boy_venta_casa_c...
# 11  http://www.properati.com.ar/15bp0_venta_casa_s...
#
#                                           description  \
# 0   2 AMBIENTES TIPO CASA PLANTA BAJA POR PASILLO,...
# 1   Venta de departamento en décimo piso al frente...
# 2   2 AMBIENTES 3ER PISO LATERAL LIVING COMEDOR AM...
# 3   PH 3 ambientes con patio. Hay 3 deptos en lote...
# 4   DEPARTAMENTO CON FANTÁSTICA ILUMINACIÓN NATURA...
# 5   Casa en el perímetro del barrio 338, ubicada e...
# 6   MUY BUEN PH AL FRENTE CON ENTRADA INDEPENDIENT...
# 7   EXCELENTE MONOAMBIENTE A ESTRENAR AMPLIO SUPER...
# 8   EXCELENTE DOS AMBIENTES  ESTRENAR AMPLIO SUPER...
# 9   MEDNOZA AL 7600A UNA CUADRA DE CALLE MENDOZAWH...
# 10  Hermosa casa sin terminar de 3 dormitorios, ba...
# 11  Entrada de Coche, Jardin, Living en desnivel, ...
#
#                                                 title  \
# 0                  2 AMB TIPO CASA SIN EXPENSAS EN PB
# 1   VENTA Depto 2 dorm. a estrenar 7 e/ 36 y 37   ...
# 2            2 AMB 3ER PISO CON ASCENSOR APTO CREDITO
# 3                        PH 3 amb. cfte. reciclado
# 4   DEPTO 2 AMB AL CONTRAFRENTE ZONA CENTRO/PLAZA ...
# 5   Casa Barrio 338. Sobre calle 3 de caballería, ...
# 6   MUY BUEN PH AL FRENTE DOS DORMITORIOS , PATIO,...
# 7   JOSE HERNANDEZ 1400 MONOAMBIENTE  ESTRENAR CAT...
# 8   JOSE HERNANDEZ   1400 DOS AMBIENTES ESTRENAR ,...
# 9          WHITE 7637 - 2 DORMITORIOS CON PATIO
# 10  Casa sin terminar en Falda de Cañete.         ...
# 11                                            CHALET
#
#                                       image_thumbnail     id  ambientes_tit  \
# 0   https://thumbs4.properati.com/8/BluUYiHJLhgIIK...  15bo8              2
# 1   https://thumbs4.properati.com/7/ikpVBu2ztHA7jv...  15bob              2
# 2   https://thumbs4.properati.com/5/SXKr34F_IwG3W_...  15bod              2
# 3   https://thumbs4.properati.com/3/DgIfX-85Mog5SP...  15boh              3
# 4   https://thumbs4.properati.com/5/xrRqlNcSI_vs-f...  15bok              2
# 5   https://thumbs4.properati.com/6/q-w68gvaUEQVXI...  15bop
# 6   https://thumbs4.properati.com/5/6GOXsHCyDu1aGx...  15bor
# 7   https://thumbs4.properati.com/1/IHxARynlr8sPEW...  15bot
# 8   https://thumbs4.properati.com/2/J3zOjgaFHrkvnv...  15bou
# 9   https://thumbs4.properati.com/8/RCf1YEWdF4rv98...  15box              2
# 10  https://thumbs4.properati.com/3/mQkhIxXpTTbMSc...  15boy
# 11  https://thumbs4.properati.com/4/pH0MnS_2zCGOHR...  15bp0
#
#     ambientes_descrip
# 0                   2
# 1
# 2                   2
# 3                   3
# 4                   1
# 5
# 6
# 7
# 8
# 9                   2
# 10                  3
# 11                 12
#
# [12 rows x 28 columns]

# %%
#completamos los valores faltantes NaN con los valores que sacamos de la columna título, que llamamos 'ambientes_tit'
df['rooms'] = df['rooms'].fillna(df['ambientes_tit'])
df.head(12)
# Out:
#    operation property_type    place_name  \
# 0       sell            PH     Mataderos
# 1       sell     apartment      La Plata
# 2       sell     apartment     Mataderos
# 3       sell            PH       Liniers
# 4       sell     apartment        Centro
# 5       sell         house  Gualeguaychú
# 6       sell            PH         Munro
# 7       sell     apartment      Belgrano
# 8       sell     apartment      Belgrano
# 9       sell         house       Rosario
# 10      sell         house       Córdoba
# 11      sell         house    San Miguel
#
#                               place_with_parent_names country_name  \
# 0               |Argentina|Capital Federal|Mataderos|    Argentina
# 1         |Argentina|Bs.As. G.B.A. Zona Sur|La Plata|    Argentina
# 2               |Argentina|Capital Federal|Mataderos|    Argentina
# 3                 |Argentina|Capital Federal|Liniers|    Argentina
# 4   |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
# 5                 |Argentina|Entre Ríos|Gualeguaychú|    Argentina
# 6   |Argentina|Bs.As. G.B.A. Zona Norte|Vicente Ló...    Argentina
# 7                |Argentina|Capital Federal|Belgrano|    Argentina
# 8                |Argentina|Capital Federal|Belgrano|    Argentina
# 9                        |Argentina|Santa Fe|Rosario|    Argentina
# 10                        |Argentina|Córdoba|Córdoba|    Argentina
# 11    |Argentina|Bs.As. G.B.A. Zona Norte|San Miguel|    Argentina
#
#                       state_name  geonames_id                  lat-lon  \
# 0                Capital Federal    3430787.0  -34.6618237,-58.5088387
# 1         Bs.As. G.B.A. Zona Sur    3432039.0  -34.9038831,-57.9643295
# 2                Capital Federal    3430787.0  -34.6522615,-58.5229825
# 3                Capital Federal    3431333.0  -34.6477969,-58.5164244
# 4   Buenos Aires Costa Atlántica    3435548.0  -38.0026256,-57.5494468
# 5                     Entre Ríos    3433657.0   -33.0140714,-58.519828
# 6       Bs.As. G.B.A. Zona Norte    3430511.0  -34.5329567,-58.5217825
# 7                Capital Federal    3436077.0   -34.5598729,-58.443362
# 8                Capital Federal    3436077.0   -34.5598729,-58.443362
# 9                       Santa Fe    3838574.0   -32.942031,-60.7259192
# 10                       Córdoba    3860259.0  -31.4200833,-64.1887761
# 11      Bs.As. G.B.A. Zona Norte          NaN  -34.5390571,-58.7196093
#
#           lat        lon  ...  floor rooms  expenses  \
# 0  -34.661824 -58.508839  ...    NaN     2       NaN
# 1  -34.903883 -57.964330  ...    NaN     2       NaN
# 2  -34.652262 -58.522982  ...    NaN     2       NaN
# 3  -34.647797 -58.516424  ...    NaN     3       NaN
# 4  -38.002626 -57.549447  ...    NaN     2       NaN
# 5  -33.014071 -58.519828  ...    NaN             NaN
# 6  -34.532957 -58.521782  ...    NaN             NaN
# 7  -34.559873 -58.443362  ...    NaN             NaN
# 8  -34.559873 -58.443362  ...    NaN             NaN
# 9  -32.942031 -60.725919  ...    NaN     2       NaN
# 10 -31.420083 -64.188776  ...    NaN             NaN
# 11 -34.539057 -58.719609  ...    NaN             NaN
#
#                                         properati_url  \
# 0   http://www.properati.com.ar/15bo8_venta_ph_mat...
# 1   http://www.properati.com.ar/15bob_venta_depart...
# 2   http://www.properati.com.ar/15bod_venta_depart...
# 3   http://www.properati.com.ar/15boh_venta_ph_lin...
# 4   http://www.properati.com.ar/15bok_venta_depart...
# 5   http://www.properati.com.ar/15bop_venta_depart...
# 6   http://www.properati.com.ar/15bor_venta_ph_mun...
# 7   http://www.properati.com.ar/15bot_venta_depart...
# 8   http://www.properati.com.ar/15bou_venta_depart...
# 9   http://www.properati.com.ar/15box_venta_casa_r...
# 10  http://www.properati.com.ar/15boy_venta_casa_c...
# 11  http://www.properati.com.ar/15bp0_venta_casa_s...
#
#                                           description  \
# 0   2 AMBIENTES TIPO CASA PLANTA BAJA POR PASILLO,...
# 1   Venta de departamento en décimo piso al frente...
# 2   2 AMBIENTES 3ER PISO LATERAL LIVING COMEDOR AM...
# 3   PH 3 ambientes con patio. Hay 3 deptos en lote...
# 4   DEPARTAMENTO CON FANTÁSTICA ILUMINACIÓN NATURA...
# 5   Casa en el perímetro del barrio 338, ubicada e...
# 6   MUY BUEN PH AL FRENTE CON ENTRADA INDEPENDIENT...
# 7   EXCELENTE MONOAMBIENTE A ESTRENAR AMPLIO SUPER...
# 8   EXCELENTE DOS AMBIENTES  ESTRENAR AMPLIO SUPER...
# 9   MEDNOZA AL 7600A UNA CUADRA DE CALLE MENDOZAWH...
# 10  Hermosa casa sin terminar de 3 dormitorios, ba...
# 11  Entrada de Coche, Jardin, Living en desnivel, ...
#
#                                                 title  \
# 0                  2 AMB TIPO CASA SIN EXPENSAS EN PB
# 1   VENTA Depto 2 dorm. a estrenar 7 e/ 36 y 37   ...
# 2            2 AMB 3ER PISO CON ASCENSOR APTO CREDITO
# 3                        PH 3 amb. cfte. reciclado
# 4   DEPTO 2 AMB AL CONTRAFRENTE ZONA CENTRO/PLAZA ...
# 5   Casa Barrio 338. Sobre calle 3 de caballería, ...
# 6   MUY BUEN PH AL FRENTE DOS DORMITORIOS , PATIO,...
# 7   JOSE HERNANDEZ 1400 MONOAMBIENTE  ESTRENAR CAT...
# 8   JOSE HERNANDEZ   1400 DOS AMBIENTES ESTRENAR ,...
# 9          WHITE 7637 - 2 DORMITORIOS CON PATIO
# 10  Casa sin terminar en Falda de Cañete.         ...
# 11                                            CHALET
#
#                                       image_thumbnail     id  ambientes_tit  \
# 0   https://thumbs4.properati.com/8/BluUYiHJLhgIIK...  15bo8              2
# 1   https://thumbs4.properati.com/7/ikpVBu2ztHA7jv...  15bob              2
# 2   https://thumbs4.properati.com/5/SXKr34F_IwG3W_...  15bod              2
# 3   https://thumbs4.properati.com/3/DgIfX-85Mog5SP...  15boh              3
# 4   https://thumbs4.properati.com/5/xrRqlNcSI_vs-f...  15bok              2
# 5   https://thumbs4.properati.com/6/q-w68gvaUEQVXI...  15bop
# 6   https://thumbs4.properati.com/5/6GOXsHCyDu1aGx...  15bor
# 7   https://thumbs4.properati.com/1/IHxARynlr8sPEW...  15bot
# 8   https://thumbs4.properati.com/2/J3zOjgaFHrkvnv...  15bou
# 9   https://thumbs4.properati.com/8/RCf1YEWdF4rv98...  15box              2
# 10  https://thumbs4.properati.com/3/mQkhIxXpTTbMSc...  15boy
# 11  https://thumbs4.properati.com/4/pH0MnS_2zCGOHR...  15bp0
#
#    ambientes_descrip
# 0                  2
# 1
# 2                  2
# 3                  3
# 4                  1
# 5
# 6
# 7
# 8
# 9                  2
# 10                 3
# 11                12
#
# [12 rows x 28 columns]

# %%
#Ahora tenemos 62053 nulos que hay que depurar
len(df.loc[df.rooms == ''])
# Out:
# 62053

# %%
# vemos que en todos los valores hay valores atípicos tanto str como float que hay que limpiar
df.rooms.unique()
# Out:
# array(['2', '3', '', 1.0, 4.0, 3.0, 2.0, 6.0, 5.0, '6', '1', '4', 10.0,
#        7.0, 9.0, 8.0, '5', 17.0, 22.0, 15.0, '9', 12.0, 11.0, '7', 14.0,
#        16.0, 20.0, '8', 13.0, '15', 25.0, 19.0, '10', 30.0, 18.0, 32.0,
#        '11', '16', '12', '14', 24.0, 31.0, 21.0, 29.0, 27.0, 23.0, 28.0],
#       dtype=object)

# %%
#Transformo a float todos los valores nuevamente
df['rooms'] = pd.to_numeric(df['rooms'], errors='coerce')

# %%
df.head(20)
# Out:
#    operation property_type      place_name  \
# 0       sell            PH       Mataderos
# 1       sell     apartment        La Plata
# 2       sell     apartment       Mataderos
# 3       sell            PH         Liniers
# 4       sell     apartment          Centro
# 5       sell         house    Gualeguaychú
# 6       sell            PH           Munro
# 7       sell     apartment        Belgrano
# 8       sell     apartment        Belgrano
# 9       sell         house         Rosario
# 10      sell         house         Córdoba
# 11      sell         house      San Miguel
# 12      sell     apartment        Martínez
# 13      sell     apartment    Palermo Soho
# 14      sell     apartment    Palermo Soho
# 15      sell         house     Bella Vista
# 16      sell            PH       Mataderos
# 17      sell     apartment  Barrio El Golf
# 18      sell         house           Tigre
# 19      sell     apartment         Palermo
#
#                               place_with_parent_names country_name  \
# 0               |Argentina|Capital Federal|Mataderos|    Argentina
# 1         |Argentina|Bs.As. G.B.A. Zona Sur|La Plata|    Argentina
# 2               |Argentina|Capital Federal|Mataderos|    Argentina
# 3                 |Argentina|Capital Federal|Liniers|    Argentina
# 4   |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
# 5                 |Argentina|Entre Ríos|Gualeguaychú|    Argentina
# 6   |Argentina|Bs.As. G.B.A. Zona Norte|Vicente Ló...    Argentina
# 7                |Argentina|Capital Federal|Belgrano|    Argentina
# 8                |Argentina|Capital Federal|Belgrano|    Argentina
# 9                        |Argentina|Santa Fe|Rosario|    Argentina
# 10                        |Argentina|Córdoba|Córdoba|    Argentina
# 11    |Argentina|Bs.As. G.B.A. Zona Norte|San Miguel|    Argentina
# 12  |Argentina|Bs.As. G.B.A. Zona Norte|San Isidro...    Argentina
# 13   |Argentina|Capital Federal|Palermo|Palermo Soho|    Argentina
# 14   |Argentina|Capital Federal|Palermo|Palermo Soho|    Argentina
# 15  |Argentina|Bs.As. G.B.A. Zona Norte|San Miguel...    Argentina
# 16              |Argentina|Capital Federal|Mataderos|    Argentina
# 17  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Nord...    Argentina
# 18         |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|    Argentina
# 19                |Argentina|Capital Federal|Palermo|    Argentina
#
#                       state_name  geonames_id                        lat-lon  \
# 0                Capital Federal    3430787.0        -34.6618237,-58.5088387
# 1         Bs.As. G.B.A. Zona Sur    3432039.0        -34.9038831,-57.9643295
# 2                Capital Federal    3430787.0        -34.6522615,-58.5229825
# 3                Capital Federal    3431333.0        -34.6477969,-58.5164244
# 4   Buenos Aires Costa Atlántica    3435548.0        -38.0026256,-57.5494468
# 5                     Entre Ríos    3433657.0         -33.0140714,-58.519828
# 6       Bs.As. G.B.A. Zona Norte    3430511.0        -34.5329567,-58.5217825
# 7                Capital Federal    3436077.0         -34.5598729,-58.443362
# 8                Capital Federal    3436077.0         -34.5598729,-58.443362
# 9                       Santa Fe    3838574.0         -32.942031,-60.7259192
# 10                       Córdoba    3860259.0        -31.4200833,-64.1887761
# 11      Bs.As. G.B.A. Zona Norte          NaN        -34.5390571,-58.7196093
# 12      Bs.As. G.B.A. Zona Norte    3430813.0        -34.4860195,-58.5038139
# 13               Capital Federal    3430234.0                            NaN
# 14               Capital Federal    3430234.0                            NaN
# 15      Bs.As. G.B.A. Zona Norte    3436061.0  -34.5879112015,-58.6987828445
# 16               Capital Federal    3430787.0  -34.6523561177,-58.5016239381
# 17      Bs.As. G.B.A. Zona Norte          NaN  -34.4087174767,-58.6343892841
# 18      Bs.As. G.B.A. Zona Norte    3427753.0         -34.425087,-58.5796585
# 19               Capital Federal    3430234.0   -34.580503566,-58.4058744847
#
#           lat        lon  ...  floor rooms  expenses  \
# 0  -34.661824 -58.508839  ...    NaN   2.0       NaN
# 1  -34.903883 -57.964330  ...    NaN   2.0       NaN
# 2  -34.652262 -58.522982  ...    NaN   2.0       NaN
# 3  -34.647797 -58.516424  ...    NaN   3.0       NaN
# 4  -38.002626 -57.549447  ...    NaN   2.0       NaN
# 5  -33.014071 -58.519828  ...    NaN   NaN       NaN
# 6  -34.532957 -58.521782  ...    NaN   NaN       NaN
# 7  -34.559873 -58.443362  ...    NaN   NaN       NaN
# 8  -34.559873 -58.443362  ...    NaN   NaN       NaN
# 9  -32.942031 -60.725919  ...    NaN   2.0       NaN
# 10 -31.420083 -64.188776  ...    NaN   NaN       NaN
# 11 -34.539057 -58.719609  ...    NaN   NaN       NaN
# 12 -34.486019 -58.503814  ...    NaN   2.0       NaN
# 13        NaN        NaN  ...    NaN   1.0       NaN
# 14        NaN        NaN  ...    NaN   1.0       NaN
# 15 -34.587911 -58.698783  ...    NaN   NaN       NaN
# 16 -34.652356 -58.501624  ...    NaN   4.0       NaN
# 17 -34.408717 -58.634389  ...    NaN   3.0       NaN
# 18 -34.425087 -58.579659  ...    NaN   NaN       NaN
# 19 -34.580504 -58.405874  ...    NaN   3.0       NaN
#
#                                         properati_url  \
# 0   http://www.properati.com.ar/15bo8_venta_ph_mat...
# 1   http://www.properati.com.ar/15bob_venta_depart...
# 2   http://www.properati.com.ar/15bod_venta_depart...
# 3   http://www.properati.com.ar/15boh_venta_ph_lin...
# 4   http://www.properati.com.ar/15bok_venta_depart...
# 5   http://www.properati.com.ar/15bop_venta_depart...
# 6   http://www.properati.com.ar/15bor_venta_ph_mun...
# 7   http://www.properati.com.ar/15bot_venta_depart...
# 8   http://www.properati.com.ar/15bou_venta_depart...
# 9   http://www.properati.com.ar/15box_venta_casa_r...
# 10  http://www.properati.com.ar/15boy_venta_casa_c...
# 11  http://www.properati.com.ar/15bp0_venta_casa_s...
# 12  http://www.properati.com.ar/15bp4_venta_depart...
# 13  http://www.properati.com.ar/15bp9_venta_depart...
# 14  http://www.properati.com.ar/15bpa_venta_depart...
# 15  http://www.properati.com.ar/15bpd_venta_casa_b...
# 16  http://www.properati.com.ar/15bpj_venta_ph_mat...
# 17  http://www.properati.com.ar/15bpl_venta_depart...
# 18  http://www.properati.com.ar/15bq1_venta_casa_t...
# 19  http://www.properati.com.ar/15bq8_venta_depart...
#
#                                           description  \
# 0   2 AMBIENTES TIPO CASA PLANTA BAJA POR PASILLO,...
# 1   Venta de departamento en décimo piso al frente...
# 2   2 AMBIENTES 3ER PISO LATERAL LIVING COMEDOR AM...
# 3   PH 3 ambientes con patio. Hay 3 deptos en lote...
# 4   DEPARTAMENTO CON FANTÁSTICA ILUMINACIÓN NATURA...
# 5   Casa en el perímetro del barrio 338, ubicada e...
# 6   MUY BUEN PH AL FRENTE CON ENTRADA INDEPENDIENT...
# 7   EXCELENTE MONOAMBIENTE A ESTRENAR AMPLIO SUPER...
# 8   EXCELENTE DOS AMBIENTES  ESTRENAR AMPLIO SUPER...
# 9   MEDNOZA AL 7600A UNA CUADRA DE CALLE MENDOZAWH...
# 10  Hermosa casa sin terminar de 3 dormitorios, ba...
# 11  Entrada de Coche, Jardin, Living en desnivel, ...
# 12  EXCELENTE DEPARTAMENTO 2 AMBIENTES CONTRAFRENT...
# 13   Torre I Mondrian. 3 ambientes con terraza y d...
# 14  Torre II Dalí. Ambiente unico divisible.Vitrau...
# 15  ULTIMA UNIDAD DISPONIBLEHAUS BOULEVARD: Metros...
# 16  Ventas Mataderos al frente Duplex 4 amb.- Plan...
# 17  Excelente 3 ambientes en un 6 piso y con terra...
# 18  Casa sobre lote al golf en barrio San Isidro L...
# 19  Excelente semipiso al contra frente en Bulnes ...
#
#                                                 title  \
# 0                  2 AMB TIPO CASA SIN EXPENSAS EN PB
# 1   VENTA Depto 2 dorm. a estrenar 7 e/ 36 y 37   ...
# 2            2 AMB 3ER PISO CON ASCENSOR APTO CREDITO
# 3                        PH 3 amb. cfte. reciclado
# 4   DEPTO 2 AMB AL CONTRAFRENTE ZONA CENTRO/PLAZA ...
# 5   Casa Barrio 338. Sobre calle 3 de caballería, ...
# 6   MUY BUEN PH AL FRENTE DOS DORMITORIOS , PATIO,...
# 7   JOSE HERNANDEZ 1400 MONOAMBIENTE  ESTRENAR CAT...
# 8   JOSE HERNANDEZ   1400 DOS AMBIENTES ESTRENAR ,...
# 9          WHITE 7637 - 2 DORMITORIOS CON PATIO
# 10  Casa sin terminar en Falda de Cañete.         ...
# 11                                            CHALET
# 12  EXCELENTE DEPARTAMENTO 2 AMBIENTES CONTRAFRENT...
# 13                                    Vitraux Palermo
# 14                                    Vitraux Palermo
# 15  HAUS VILLAGE / BELLA VISTA / 115m² MAS PATIO /...
# 16                      VENTA-MATADEROS-DUPLEX 4 AMB.
# 17  3 ambientes en venta en Acqua Golf 1 en Nordel...
# 18  Casa en venta en barrio San Isidro Labrador, T...
# 19  Bulnes y Libertador: espectacular pulmón, con ...
#
#                                       image_thumbnail     id  ambientes_tit  \
# 0   https://thumbs4.properati.com/8/BluUYiHJLhgIIK...  15bo8              2
# 1   https://thumbs4.properati.com/7/ikpVBu2ztHA7jv...  15bob              2
# 2   https://thumbs4.properati.com/5/SXKr34F_IwG3W_...  15bod              2
# 3   https://thumbs4.properati.com/3/DgIfX-85Mog5SP...  15boh              3
# 4   https://thumbs4.properati.com/5/xrRqlNcSI_vs-f...  15bok              2
# 5   https://thumbs4.properati.com/6/q-w68gvaUEQVXI...  15bop
# 6   https://thumbs4.properati.com/5/6GOXsHCyDu1aGx...  15bor
# 7   https://thumbs4.properati.com/1/IHxARynlr8sPEW...  15bot
# 8   https://thumbs4.properati.com/2/J3zOjgaFHrkvnv...  15bou
# 9   https://thumbs4.properati.com/8/RCf1YEWdF4rv98...  15box              2
# 10  https://thumbs4.properati.com/3/mQkhIxXpTTbMSc...  15boy
# 11  https://thumbs4.properati.com/4/pH0MnS_2zCGOHR...  15bp0
# 12  https://thumbs4.properati.com/6/wgSui4rTYqPncO...  15bp4              2
# 13  https://thumbs4.properati.com/2/ZTUjkRzTz6YvcU...  15bp9
# 14  https://thumbs4.properati.com/8/Uay2dC732CNlRw...  15bpa
# 15  https://thumbs4.properati.com/6/F7EIhDPQfafSlp...  15bpd
# 16  https://thumbs4.properati.com/7/XSdJtiE8ZkWgon...  15bpj              4
# 17  https://thumbs4.properati.com/8/txJsOWitsI5tjM...  15bpl              3
# 18  https://thumbs4.properati.com/6/4N9cpurqmDMKEX...  15bq1
# 19  https://thumbs4.properati.com/8/1y9fKHLee-aQQj...  15bq8
#
#     ambientes_descrip
# 0                   2
# 1
# 2                   2
# 3                   3
# 4                   1
# 5
# 6
# 7
# 8
# 9                   2
# 10                  3
# 11                 12
# 12                230
# 13                  3
# 14
# 15                  3
# 16                 43
# 17                  3
# 18
# 19
#
# [20 rows x 28 columns]

# %%
#veo cuales son los valores que tiene mi columna 'rooms'
df.rooms.unique()
# Out:
# array([ 2.,  3., nan,  1.,  4.,  6.,  5., 10.,  7.,  9.,  8., 17., 22.,
#        15., 12., 11., 14., 16., 20., 13., 25., 19., 30., 18., 32., 24.,
#        31., 21., 29., 27., 23., 28.])

# %%
#ahora rellenamos los NaN con los valores de los ambientes que extraimos de la descripción incluidos en la columna 'ambientes_descrip'
df['rooms'] = df['rooms'].fillna(df['ambientes_descrip'])
df.head(20)
# Out:
#    operation property_type      place_name  \
# 0       sell            PH       Mataderos
# 1       sell     apartment        La Plata
# 2       sell     apartment       Mataderos
# 3       sell            PH         Liniers
# 4       sell     apartment          Centro
# 5       sell         house    Gualeguaychú
# 6       sell            PH           Munro
# 7       sell     apartment        Belgrano
# 8       sell     apartment        Belgrano
# 9       sell         house         Rosario
# 10      sell         house         Córdoba
# 11      sell         house      San Miguel
# 12      sell     apartment        Martínez
# 13      sell     apartment    Palermo Soho
# 14      sell     apartment    Palermo Soho
# 15      sell         house     Bella Vista
# 16      sell            PH       Mataderos
# 17      sell     apartment  Barrio El Golf
# 18      sell         house           Tigre
# 19      sell     apartment         Palermo
#
#                               place_with_parent_names country_name  \
# 0               |Argentina|Capital Federal|Mataderos|    Argentina
# 1         |Argentina|Bs.As. G.B.A. Zona Sur|La Plata|    Argentina
# 2               |Argentina|Capital Federal|Mataderos|    Argentina
# 3                 |Argentina|Capital Federal|Liniers|    Argentina
# 4   |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
# 5                 |Argentina|Entre Ríos|Gualeguaychú|    Argentina
# 6   |Argentina|Bs.As. G.B.A. Zona Norte|Vicente Ló...    Argentina
# 7                |Argentina|Capital Federal|Belgrano|    Argentina
# 8                |Argentina|Capital Federal|Belgrano|    Argentina
# 9                        |Argentina|Santa Fe|Rosario|    Argentina
# 10                        |Argentina|Córdoba|Córdoba|    Argentina
# 11    |Argentina|Bs.As. G.B.A. Zona Norte|San Miguel|    Argentina
# 12  |Argentina|Bs.As. G.B.A. Zona Norte|San Isidro...    Argentina
# 13   |Argentina|Capital Federal|Palermo|Palermo Soho|    Argentina
# 14   |Argentina|Capital Federal|Palermo|Palermo Soho|    Argentina
# 15  |Argentina|Bs.As. G.B.A. Zona Norte|San Miguel...    Argentina
# 16              |Argentina|Capital Federal|Mataderos|    Argentina
# 17  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Nord...    Argentina
# 18         |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|    Argentina
# 19                |Argentina|Capital Federal|Palermo|    Argentina
#
#                       state_name  geonames_id                        lat-lon  \
# 0                Capital Federal    3430787.0        -34.6618237,-58.5088387
# 1         Bs.As. G.B.A. Zona Sur    3432039.0        -34.9038831,-57.9643295
# 2                Capital Federal    3430787.0        -34.6522615,-58.5229825
# 3                Capital Federal    3431333.0        -34.6477969,-58.5164244
# 4   Buenos Aires Costa Atlántica    3435548.0        -38.0026256,-57.5494468
# 5                     Entre Ríos    3433657.0         -33.0140714,-58.519828
# 6       Bs.As. G.B.A. Zona Norte    3430511.0        -34.5329567,-58.5217825
# 7                Capital Federal    3436077.0         -34.5598729,-58.443362
# 8                Capital Federal    3436077.0         -34.5598729,-58.443362
# 9                       Santa Fe    3838574.0         -32.942031,-60.7259192
# 10                       Córdoba    3860259.0        -31.4200833,-64.1887761
# 11      Bs.As. G.B.A. Zona Norte          NaN        -34.5390571,-58.7196093
# 12      Bs.As. G.B.A. Zona Norte    3430813.0        -34.4860195,-58.5038139
# 13               Capital Federal    3430234.0                            NaN
# 14               Capital Federal    3430234.0                            NaN
# 15      Bs.As. G.B.A. Zona Norte    3436061.0  -34.5879112015,-58.6987828445
# 16               Capital Federal    3430787.0  -34.6523561177,-58.5016239381
# 17      Bs.As. G.B.A. Zona Norte          NaN  -34.4087174767,-58.6343892841
# 18      Bs.As. G.B.A. Zona Norte    3427753.0         -34.425087,-58.5796585
# 19               Capital Federal    3430234.0   -34.580503566,-58.4058744847
#
#           lat        lon  ...  floor rooms  expenses  \
# 0  -34.661824 -58.508839  ...    NaN     2       NaN
# 1  -34.903883 -57.964330  ...    NaN     2       NaN
# 2  -34.652262 -58.522982  ...    NaN     2       NaN
# 3  -34.647797 -58.516424  ...    NaN     3       NaN
# 4  -38.002626 -57.549447  ...    NaN     2       NaN
# 5  -33.014071 -58.519828  ...    NaN             NaN
# 6  -34.532957 -58.521782  ...    NaN             NaN
# 7  -34.559873 -58.443362  ...    NaN             NaN
# 8  -34.559873 -58.443362  ...    NaN             NaN
# 9  -32.942031 -60.725919  ...    NaN     2       NaN
# 10 -31.420083 -64.188776  ...    NaN     3       NaN
# 11 -34.539057 -58.719609  ...    NaN    12       NaN
# 12 -34.486019 -58.503814  ...    NaN     2       NaN
# 13        NaN        NaN  ...    NaN     1       NaN
# 14        NaN        NaN  ...    NaN     1       NaN
# 15 -34.587911 -58.698783  ...    NaN     3       NaN
# 16 -34.652356 -58.501624  ...    NaN     4       NaN
# 17 -34.408717 -58.634389  ...    NaN     3       NaN
# 18 -34.425087 -58.579659  ...    NaN             NaN
# 19 -34.580504 -58.405874  ...    NaN     3       NaN
#
#                                         properati_url  \
# 0   http://www.properati.com.ar/15bo8_venta_ph_mat...
# 1   http://www.properati.com.ar/15bob_venta_depart...
# 2   http://www.properati.com.ar/15bod_venta_depart...
# 3   http://www.properati.com.ar/15boh_venta_ph_lin...
# 4   http://www.properati.com.ar/15bok_venta_depart...
# 5   http://www.properati.com.ar/15bop_venta_depart...
# 6   http://www.properati.com.ar/15bor_venta_ph_mun...
# 7   http://www.properati.com.ar/15bot_venta_depart...
# 8   http://www.properati.com.ar/15bou_venta_depart...
# 9   http://www.properati.com.ar/15box_venta_casa_r...
# 10  http://www.properati.com.ar/15boy_venta_casa_c...
# 11  http://www.properati.com.ar/15bp0_venta_casa_s...
# 12  http://www.properati.com.ar/15bp4_venta_depart...
# 13  http://www.properati.com.ar/15bp9_venta_depart...
# 14  http://www.properati.com.ar/15bpa_venta_depart...
# 15  http://www.properati.com.ar/15bpd_venta_casa_b...
# 16  http://www.properati.com.ar/15bpj_venta_ph_mat...
# 17  http://www.properati.com.ar/15bpl_venta_depart...
# 18  http://www.properati.com.ar/15bq1_venta_casa_t...
# 19  http://www.properati.com.ar/15bq8_venta_depart...
#
#                                           description  \
# 0   2 AMBIENTES TIPO CASA PLANTA BAJA POR PASILLO,...
# 1   Venta de departamento en décimo piso al frente...
# 2   2 AMBIENTES 3ER PISO LATERAL LIVING COMEDOR AM...
# 3   PH 3 ambientes con patio. Hay 3 deptos en lote...
# 4   DEPARTAMENTO CON FANTÁSTICA ILUMINACIÓN NATURA...
# 5   Casa en el perímetro del barrio 338, ubicada e...
# 6   MUY BUEN PH AL FRENTE CON ENTRADA INDEPENDIENT...
# 7   EXCELENTE MONOAMBIENTE A ESTRENAR AMPLIO SUPER...
# 8   EXCELENTE DOS AMBIENTES  ESTRENAR AMPLIO SUPER...
# 9   MEDNOZA AL 7600A UNA CUADRA DE CALLE MENDOZAWH...
# 10  Hermosa casa sin terminar de 3 dormitorios, ba...
# 11  Entrada de Coche, Jardin, Living en desnivel, ...
# 12  EXCELENTE DEPARTAMENTO 2 AMBIENTES CONTRAFRENT...
# 13   Torre I Mondrian. 3 ambientes con terraza y d...
# 14  Torre II Dalí. Ambiente unico divisible.Vitrau...
# 15  ULTIMA UNIDAD DISPONIBLEHAUS BOULEVARD: Metros...
# 16  Ventas Mataderos al frente Duplex 4 amb.- Plan...
# 17  Excelente 3 ambientes en un 6 piso y con terra...
# 18  Casa sobre lote al golf en barrio San Isidro L...
# 19  Excelente semipiso al contra frente en Bulnes ...
#
#                                                 title  \
# 0                  2 AMB TIPO CASA SIN EXPENSAS EN PB
# 1   VENTA Depto 2 dorm. a estrenar 7 e/ 36 y 37   ...
# 2            2 AMB 3ER PISO CON ASCENSOR APTO CREDITO
# 3                        PH 3 amb. cfte. reciclado
# 4   DEPTO 2 AMB AL CONTRAFRENTE ZONA CENTRO/PLAZA ...
# 5   Casa Barrio 338. Sobre calle 3 de caballería, ...
# 6   MUY BUEN PH AL FRENTE DOS DORMITORIOS , PATIO,...
# 7   JOSE HERNANDEZ 1400 MONOAMBIENTE  ESTRENAR CAT...
# 8   JOSE HERNANDEZ   1400 DOS AMBIENTES ESTRENAR ,...
# 9          WHITE 7637 - 2 DORMITORIOS CON PATIO
# 10  Casa sin terminar en Falda de Cañete.         ...
# 11                                            CHALET
# 12  EXCELENTE DEPARTAMENTO 2 AMBIENTES CONTRAFRENT...
# 13                                    Vitraux Palermo
# 14                                    Vitraux Palermo
# 15  HAUS VILLAGE / BELLA VISTA / 115m² MAS PATIO /...
# 16                      VENTA-MATADEROS-DUPLEX 4 AMB.
# 17  3 ambientes en venta en Acqua Golf 1 en Nordel...
# 18  Casa en venta en barrio San Isidro Labrador, T...
# 19  Bulnes y Libertador: espectacular pulmón, con ...
#
#                                       image_thumbnail     id  ambientes_tit  \
# 0   https://thumbs4.properati.com/8/BluUYiHJLhgIIK...  15bo8              2
# 1   https://thumbs4.properati.com/7/ikpVBu2ztHA7jv...  15bob              2
# 2   https://thumbs4.properati.com/5/SXKr34F_IwG3W_...  15bod              2
# 3   https://thumbs4.properati.com/3/DgIfX-85Mog5SP...  15boh              3
# 4   https://thumbs4.properati.com/5/xrRqlNcSI_vs-f...  15bok              2
# 5   https://thumbs4.properati.com/6/q-w68gvaUEQVXI...  15bop
# 6   https://thumbs4.properati.com/5/6GOXsHCyDu1aGx...  15bor
# 7   https://thumbs4.properati.com/1/IHxARynlr8sPEW...  15bot
# 8   https://thumbs4.properati.com/2/J3zOjgaFHrkvnv...  15bou
# 9   https://thumbs4.properati.com/8/RCf1YEWdF4rv98...  15box              2
# 10  https://thumbs4.properati.com/3/mQkhIxXpTTbMSc...  15boy
# 11  https://thumbs4.properati.com/4/pH0MnS_2zCGOHR...  15bp0
# 12  https://thumbs4.properati.com/6/wgSui4rTYqPncO...  15bp4              2
# 13  https://thumbs4.properati.com/2/ZTUjkRzTz6YvcU...  15bp9
# 14  https://thumbs4.properati.com/8/Uay2dC732CNlRw...  15bpa
# 15  https://thumbs4.properati.com/6/F7EIhDPQfafSlp...  15bpd
# 16  https://thumbs4.properati.com/7/XSdJtiE8ZkWgon...  15bpj              4
# 17  https://thumbs4.properati.com/8/txJsOWitsI5tjM...  15bpl              3
# 18  https://thumbs4.properati.com/6/4N9cpurqmDMKEX...  15bq1
# 19  https://thumbs4.properati.com/8/1y9fKHLee-aQQj...  15bq8
#
#    ambientes_descrip
# 0                  2
# 1
# 2                  2
# 3                  3
# 4                  1
# 5
# 6
# 7
# 8
# 9                  2
# 10                 3
# 11                12
# 12               230
# 13                 3
# 14
# 15                 3
# 16                43
# 17                 3
# 18
# 19
#
# [20 rows x 28 columns]

# %%
#vemos que al agregar nuevos registros, tenemos valores atípicos. También tenemos tanto floats como str
df['rooms'].unique()
# Out:
# array([2.0, 3.0, '', '3', '12', 1.0, 4.0, 6.0, '2', 5.0, '1', '4', '32',
#        10.0, 7.0, 9.0, 8.0, '74', '5', '24', '43', '63', '6', '53', 17.0,
#        22.0, '52', '21', '35', '62', '31', 15.0, '11', '54', '9', '23',
#        '7', '42', '48', 12.0, '73', 11.0, 14.0, 16.0, '93', '22', 20.0,
#        '77', '33', 13.0, '34', '43800', '2017', '103', '41', '297', '072',
#        '64', '102', '742', '57', '622', '61', '714', '511', '8', '2140',
#        25.0, '65', '10', '532', '51', '30', '22130', '365003', '44', 19.0,
#        '422', '72', '88', '109', '330', '150', '600', '652', '610', '13',
#        '421', '83', '631', '542', '1042', '27', '20', 30.0, '170', '87',
#        '94', '71', '632', '26', '75', '323', 18.0, '711', '403', '14',
#        '621', '00022', 32.0, '23001', '17', '100', '201741', '80',
#        '42181824', '113', '613', '18', '3204', '92', '222', '342', '5210',
#        '29', '125', '2000', '1000', '124', '55', '233', '485', '000',
#        '00', '25', '90', '50', '9014', '84', '0001', '902', '772', '140',
#        '350', '117', '5001', '141', '47', '400', '60', '211', '644',
#        '5104', '662', '431', '82', '45', '423', '315', '322', '4000',
#        '326', '98', '76', '85', '1500', '2170', '3170', '148', '15',
#        '6003', '432', '602', '28', '19754', '232', '66', '722', '05',
#        24.0, 31.0, 21.0, 29.0, '218', 27.0, 23.0, '40', '56', 28.0,
#        '20173', '36', '5802', '104'], dtype=object)

# %%
#previo a limpiar los valores atípicos tenemos 31674 registros
len(df.loc[df.rooms == ''])
# Out:
# 31674

# %%
#Probamos como limpiar un str..
df.rooms=df.rooms.replace('12','')

# %%
df.head(12)
# Out:
#    operation property_type    place_name  \
# 0       sell            PH     Mataderos
# 1       sell     apartment      La Plata
# 2       sell     apartment     Mataderos
# 3       sell            PH       Liniers
# 4       sell     apartment        Centro
# 5       sell         house  Gualeguaychú
# 6       sell            PH         Munro
# 7       sell     apartment      Belgrano
# 8       sell     apartment      Belgrano
# 9       sell         house       Rosario
# 10      sell         house       Córdoba
# 11      sell         house    San Miguel
#
#                               place_with_parent_names country_name  \
# 0               |Argentina|Capital Federal|Mataderos|    Argentina
# 1         |Argentina|Bs.As. G.B.A. Zona Sur|La Plata|    Argentina
# 2               |Argentina|Capital Federal|Mataderos|    Argentina
# 3                 |Argentina|Capital Federal|Liniers|    Argentina
# 4   |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
# 5                 |Argentina|Entre Ríos|Gualeguaychú|    Argentina
# 6   |Argentina|Bs.As. G.B.A. Zona Norte|Vicente Ló...    Argentina
# 7                |Argentina|Capital Federal|Belgrano|    Argentina
# 8                |Argentina|Capital Federal|Belgrano|    Argentina
# 9                        |Argentina|Santa Fe|Rosario|    Argentina
# 10                        |Argentina|Córdoba|Córdoba|    Argentina
# 11    |Argentina|Bs.As. G.B.A. Zona Norte|San Miguel|    Argentina
#
#                       state_name  geonames_id                  lat-lon  \
# 0                Capital Federal    3430787.0  -34.6618237,-58.5088387
# 1         Bs.As. G.B.A. Zona Sur    3432039.0  -34.9038831,-57.9643295
# 2                Capital Federal    3430787.0  -34.6522615,-58.5229825
# 3                Capital Federal    3431333.0  -34.6477969,-58.5164244
# 4   Buenos Aires Costa Atlántica    3435548.0  -38.0026256,-57.5494468
# 5                     Entre Ríos    3433657.0   -33.0140714,-58.519828
# 6       Bs.As. G.B.A. Zona Norte    3430511.0  -34.5329567,-58.5217825
# 7                Capital Federal    3436077.0   -34.5598729,-58.443362
# 8                Capital Federal    3436077.0   -34.5598729,-58.443362
# 9                       Santa Fe    3838574.0   -32.942031,-60.7259192
# 10                       Córdoba    3860259.0  -31.4200833,-64.1887761
# 11      Bs.As. G.B.A. Zona Norte          NaN  -34.5390571,-58.7196093
#
#           lat        lon  ...  floor rooms  expenses  \
# 0  -34.661824 -58.508839  ...    NaN     2       NaN
# 1  -34.903883 -57.964330  ...    NaN     2       NaN
# 2  -34.652262 -58.522982  ...    NaN     2       NaN
# 3  -34.647797 -58.516424  ...    NaN     3       NaN
# 4  -38.002626 -57.549447  ...    NaN     2       NaN
# 5  -33.014071 -58.519828  ...    NaN             NaN
# 6  -34.532957 -58.521782  ...    NaN             NaN
# 7  -34.559873 -58.443362  ...    NaN             NaN
# 8  -34.559873 -58.443362  ...    NaN             NaN
# 9  -32.942031 -60.725919  ...    NaN     2       NaN
# 10 -31.420083 -64.188776  ...    NaN     3       NaN
# 11 -34.539057 -58.719609  ...    NaN             NaN
#
#                                         properati_url  \
# 0   http://www.properati.com.ar/15bo8_venta_ph_mat...
# 1   http://www.properati.com.ar/15bob_venta_depart...
# 2   http://www.properati.com.ar/15bod_venta_depart...
# 3   http://www.properati.com.ar/15boh_venta_ph_lin...
# 4   http://www.properati.com.ar/15bok_venta_depart...
# 5   http://www.properati.com.ar/15bop_venta_depart...
# 6   http://www.properati.com.ar/15bor_venta_ph_mun...
# 7   http://www.properati.com.ar/15bot_venta_depart...
# 8   http://www.properati.com.ar/15bou_venta_depart...
# 9   http://www.properati.com.ar/15box_venta_casa_r...
# 10  http://www.properati.com.ar/15boy_venta_casa_c...
# 11  http://www.properati.com.ar/15bp0_venta_casa_s...
#
#                                           description  \
# 0   2 AMBIENTES TIPO CASA PLANTA BAJA POR PASILLO,...
# 1   Venta de departamento en décimo piso al frente...
# 2   2 AMBIENTES 3ER PISO LATERAL LIVING COMEDOR AM...
# 3   PH 3 ambientes con patio. Hay 3 deptos en lote...
# 4   DEPARTAMENTO CON FANTÁSTICA ILUMINACIÓN NATURA...
# 5   Casa en el perímetro del barrio 338, ubicada e...
# 6   MUY BUEN PH AL FRENTE CON ENTRADA INDEPENDIENT...
# 7   EXCELENTE MONOAMBIENTE A ESTRENAR AMPLIO SUPER...
# 8   EXCELENTE DOS AMBIENTES  ESTRENAR AMPLIO SUPER...
# 9   MEDNOZA AL 7600A UNA CUADRA DE CALLE MENDOZAWH...
# 10  Hermosa casa sin terminar de 3 dormitorios, ba...
# 11  Entrada de Coche, Jardin, Living en desnivel, ...
#
#                                                 title  \
# 0                  2 AMB TIPO CASA SIN EXPENSAS EN PB
# 1   VENTA Depto 2 dorm. a estrenar 7 e/ 36 y 37   ...
# 2            2 AMB 3ER PISO CON ASCENSOR APTO CREDITO
# 3                        PH 3 amb. cfte. reciclado
# 4   DEPTO 2 AMB AL CONTRAFRENTE ZONA CENTRO/PLAZA ...
# 5   Casa Barrio 338. Sobre calle 3 de caballería, ...
# 6   MUY BUEN PH AL FRENTE DOS DORMITORIOS , PATIO,...
# 7   JOSE HERNANDEZ 1400 MONOAMBIENTE  ESTRENAR CAT...
# 8   JOSE HERNANDEZ   1400 DOS AMBIENTES ESTRENAR ,...
# 9          WHITE 7637 - 2 DORMITORIOS CON PATIO
# 10  Casa sin terminar en Falda de Cañete.         ...
# 11                                            CHALET
#
#                                       image_thumbnail     id  ambientes_tit  \
# 0   https://thumbs4.properati.com/8/BluUYiHJLhgIIK...  15bo8              2
# 1   https://thumbs4.properati.com/7/ikpVBu2ztHA7jv...  15bob              2
# 2   https://thumbs4.properati.com/5/SXKr34F_IwG3W_...  15bod              2
# 3   https://thumbs4.properati.com/3/DgIfX-85Mog5SP...  15boh              3
# 4   https://thumbs4.properati.com/5/xrRqlNcSI_vs-f...  15bok              2
# 5   https://thumbs4.properati.com/6/q-w68gvaUEQVXI...  15bop
# 6   https://thumbs4.properati.com/5/6GOXsHCyDu1aGx...  15bor
# 7   https://thumbs4.properati.com/1/IHxARynlr8sPEW...  15bot
# 8   https://thumbs4.properati.com/2/J3zOjgaFHrkvnv...  15bou
# 9   https://thumbs4.properati.com/8/RCf1YEWdF4rv98...  15box              2
# 10  https://thumbs4.properati.com/3/mQkhIxXpTTbMSc...  15boy
# 11  https://thumbs4.properati.com/4/pH0MnS_2zCGOHR...  15bp0
#
#    ambientes_descrip
# 0                  2
# 1
# 2                  2
# 3                  3
# 4                  1
# 5
# 6
# 7
# 8
# 9                  2
# 10                 3
# 11                12
#
# [12 rows x 28 columns]

# %%
type(df.rooms.iloc[11])
# Out:
# str

# %%
#reemplazamos los str y floats para todos los valores atípicos
df.rooms=df.rooms.replace('32',3.0).replace('74','').replace('24','').replace('43',4.0)
df.rooms=df.rooms.replace('63',6.0).replace('53',5.0).replace('52',5.0).replace('21',2.0).replace('35',3.0)
df.rooms=df.rooms.replace('62','').replace('31',3.0).replace('11','').replace('54',5.0).replace('23','')
df.rooms=df.rooms.replace('42',4.0).replace('48','').replace('73','').replace('93','').replace('22',2.0)
df.rooms=df.rooms.replace('33',3.0).replace('34',3.0).replace('43800','').replace('2017','').replace('103','')
df.rooms=df.rooms.replace('41','').replace('297','').replace('072','').replace('64','6').replace('102','')
df.rooms=df.rooms.replace('742','').replace('57','').replace('622','').replace('61','6').replace('714','')
df.rooms=df.rooms.replace('511',5.0).replace('2140','').replace('65','').replace('532','').replace('51','')
df.rooms=df.rooms.replace('30',3.0).replace('22130','').replace('365003','').replace('44',4.0).replace('422',4.0)
df.rooms=df.rooms.replace('72','').replace('88','').replace('109','').replace('330',3.0).replace('150','')
df.rooms=df.rooms.replace('600','').replace('652','').replace('610','').replace('13','').replace('421',4.0)
df.rooms=df.rooms.replace('83','').replace('631','').replace('26','').replace('75','').replace('323','')
df.rooms=df.rooms.replace('711','').replace('403','').replace('14','').replace('621','').replace('00022','')
df.rooms=df.rooms.replace('23001','').replace('100','').replace('17','').replace('100','').replace('201741','')
df.rooms=df.rooms.replace('42181824','').replace('113','').replace('613','').replace('18','').replace('3204','')
df.rooms=df.rooms.replace('92','').replace('222',2.0).replace('342','').replace('5210','').replace('29','')
df.rooms=df.rooms.replace('125','').replace('2000','').replace('1000','').replace('124','').replace('55',5.0)
df.rooms=df.rooms.replace('233','').replace('485','').replace('000','').replace('00','').replace('25','')
df.rooms=df.rooms.replace('90','').replace('50','').replace('9014','').replace('84','').replace('0001','')
df.rooms=df.rooms.replace('902','').replace('772','').replace('140','').replace('350','').replace('117','')
df.rooms=df.rooms.replace('5001','').replace('141','').replace('47','').replace('400','').replace('60','')
df.rooms=df.rooms.replace('2',2.0).replace('644','').replace('5104','').replace('662','').replace('431','')
df.rooms=df.rooms.replace('82','').replace('45','').replace('423','').replace('315','').replace('322',3.0)
df.rooms=df.rooms.replace('4000','').replace('326','').replace('98','').replace('76','').replace('85','')
df.rooms=df.rooms.replace('1500','').replace('2170','').replace('3170','').replace('148','').replace('15','')
df.rooms=df.rooms.replace('6003','').replace('432','').replace('602','').replace('28','').replace('19754','')
df.rooms=df.rooms.replace('232','').replace('66','').replace('722','').replace('05','5').replace('56','')
df.rooms=df.rooms.replace('20173','').replace('36','').replace('5802','').replace('104','')

# %%
df.head(12)
# Out:
#    operation property_type    place_name  \
# 0       sell            PH     Mataderos
# 1       sell     apartment      La Plata
# 2       sell     apartment     Mataderos
# 3       sell            PH       Liniers
# 4       sell     apartment        Centro
# 5       sell         house  Gualeguaychú
# 6       sell            PH         Munro
# 7       sell     apartment      Belgrano
# 8       sell     apartment      Belgrano
# 9       sell         house       Rosario
# 10      sell         house       Córdoba
# 11      sell         house    San Miguel
#
#                               place_with_parent_names country_name  \
# 0               |Argentina|Capital Federal|Mataderos|    Argentina
# 1         |Argentina|Bs.As. G.B.A. Zona Sur|La Plata|    Argentina
# 2               |Argentina|Capital Federal|Mataderos|    Argentina
# 3                 |Argentina|Capital Federal|Liniers|    Argentina
# 4   |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
# 5                 |Argentina|Entre Ríos|Gualeguaychú|    Argentina
# 6   |Argentina|Bs.As. G.B.A. Zona Norte|Vicente Ló...    Argentina
# 7                |Argentina|Capital Federal|Belgrano|    Argentina
# 8                |Argentina|Capital Federal|Belgrano|    Argentina
# 9                        |Argentina|Santa Fe|Rosario|    Argentina
# 10                        |Argentina|Córdoba|Córdoba|    Argentina
# 11    |Argentina|Bs.As. G.B.A. Zona Norte|San Miguel|    Argentina
#
#                       state_name  geonames_id                  lat-lon  \
# 0                Capital Federal    3430787.0  -34.6618237,-58.5088387
# 1         Bs.As. G.B.A. Zona Sur    3432039.0  -34.9038831,-57.9643295
# 2                Capital Federal    3430787.0  -34.6522615,-58.5229825
# 3                Capital Federal    3431333.0  -34.6477969,-58.5164244
# 4   Buenos Aires Costa Atlántica    3435548.0  -38.0026256,-57.5494468
# 5                     Entre Ríos    3433657.0   -33.0140714,-58.519828
# 6       Bs.As. G.B.A. Zona Norte    3430511.0  -34.5329567,-58.5217825
# 7                Capital Federal    3436077.0   -34.5598729,-58.443362
# 8                Capital Federal    3436077.0   -34.5598729,-58.443362
# 9                       Santa Fe    3838574.0   -32.942031,-60.7259192
# 10                       Córdoba    3860259.0  -31.4200833,-64.1887761
# 11      Bs.As. G.B.A. Zona Norte          NaN  -34.5390571,-58.7196093
#
#           lat        lon  ...  floor rooms  expenses  \
# 0  -34.661824 -58.508839  ...    NaN     2       NaN
# 1  -34.903883 -57.964330  ...    NaN     2       NaN
# 2  -34.652262 -58.522982  ...    NaN     2       NaN
# 3  -34.647797 -58.516424  ...    NaN     3       NaN
# 4  -38.002626 -57.549447  ...    NaN     2       NaN
# 5  -33.014071 -58.519828  ...    NaN             NaN
# 6  -34.532957 -58.521782  ...    NaN             NaN
# 7  -34.559873 -58.443362  ...    NaN             NaN
# 8  -34.559873 -58.443362  ...    NaN             NaN
# 9  -32.942031 -60.725919  ...    NaN     2       NaN
# 10 -31.420083 -64.188776  ...    NaN     3       NaN
# 11 -34.539057 -58.719609  ...    NaN             NaN
#
#                                         properati_url  \
# 0   http://www.properati.com.ar/15bo8_venta_ph_mat...
# 1   http://www.properati.com.ar/15bob_venta_depart...
# 2   http://www.properati.com.ar/15bod_venta_depart...
# 3   http://www.properati.com.ar/15boh_venta_ph_lin...
# 4   http://www.properati.com.ar/15bok_venta_depart...
# 5   http://www.properati.com.ar/15bop_venta_depart...
# 6   http://www.properati.com.ar/15bor_venta_ph_mun...
# 7   http://www.properati.com.ar/15bot_venta_depart...
# 8   http://www.properati.com.ar/15bou_venta_depart...
# 9   http://www.properati.com.ar/15box_venta_casa_r...
# 10  http://www.properati.com.ar/15boy_venta_casa_c...
# 11  http://www.properati.com.ar/15bp0_venta_casa_s...
#
#                                           description  \
# 0   2 AMBIENTES TIPO CASA PLANTA BAJA POR PASILLO,...
# 1   Venta de departamento en décimo piso al frente...
# 2   2 AMBIENTES 3ER PISO LATERAL LIVING COMEDOR AM...
# 3   PH 3 ambientes con patio. Hay 3 deptos en lote...
# 4   DEPARTAMENTO CON FANTÁSTICA ILUMINACIÓN NATURA...
# 5   Casa en el perímetro del barrio 338, ubicada e...
# 6   MUY BUEN PH AL FRENTE CON ENTRADA INDEPENDIENT...
# 7   EXCELENTE MONOAMBIENTE A ESTRENAR AMPLIO SUPER...
# 8   EXCELENTE DOS AMBIENTES  ESTRENAR AMPLIO SUPER...
# 9   MEDNOZA AL 7600A UNA CUADRA DE CALLE MENDOZAWH...
# 10  Hermosa casa sin terminar de 3 dormitorios, ba...
# 11  Entrada de Coche, Jardin, Living en desnivel, ...
#
#                                                 title  \
# 0                  2 AMB TIPO CASA SIN EXPENSAS EN PB
# 1   VENTA Depto 2 dorm. a estrenar 7 e/ 36 y 37   ...
# 2            2 AMB 3ER PISO CON ASCENSOR APTO CREDITO
# 3                        PH 3 amb. cfte. reciclado
# 4   DEPTO 2 AMB AL CONTRAFRENTE ZONA CENTRO/PLAZA ...
# 5   Casa Barrio 338. Sobre calle 3 de caballería, ...
# 6   MUY BUEN PH AL FRENTE DOS DORMITORIOS , PATIO,...
# 7   JOSE HERNANDEZ 1400 MONOAMBIENTE  ESTRENAR CAT...
# 8   JOSE HERNANDEZ   1400 DOS AMBIENTES ESTRENAR ,...
# 9          WHITE 7637 - 2 DORMITORIOS CON PATIO
# 10  Casa sin terminar en Falda de Cañete.         ...
# 11                                            CHALET
#
#                                       image_thumbnail     id  ambientes_tit  \
# 0   https://thumbs4.properati.com/8/BluUYiHJLhgIIK...  15bo8              2
# 1   https://thumbs4.properati.com/7/ikpVBu2ztHA7jv...  15bob              2
# 2   https://thumbs4.properati.com/5/SXKr34F_IwG3W_...  15bod              2
# 3   https://thumbs4.properati.com/3/DgIfX-85Mog5SP...  15boh              3
# 4   https://thumbs4.properati.com/5/xrRqlNcSI_vs-f...  15bok              2
# 5   https://thumbs4.properati.com/6/q-w68gvaUEQVXI...  15bop
# 6   https://thumbs4.properati.com/5/6GOXsHCyDu1aGx...  15bor
# 7   https://thumbs4.properati.com/1/IHxARynlr8sPEW...  15bot
# 8   https://thumbs4.properati.com/2/J3zOjgaFHrkvnv...  15bou
# 9   https://thumbs4.properati.com/8/RCf1YEWdF4rv98...  15box              2
# 10  https://thumbs4.properati.com/3/mQkhIxXpTTbMSc...  15boy
# 11  https://thumbs4.properati.com/4/pH0MnS_2zCGOHR...  15bp0
#
#    ambientes_descrip
# 0                  2
# 1
# 2                  2
# 3                  3
# 4                  1
# 5
# 6
# 7
# 8
# 9                  2
# 10                 3
# 11                12
#
# [12 rows x 28 columns]

# %%
# vemos con qué valores nos quedamos 
df['rooms'].unique()
# Out:
# array([2.0, 3.0, '', '3', 1.0, 4.0, 6.0, 5.0, '1', '4', 10.0, 7.0, 9.0,
#        8.0, '5', '6', 17.0, 22.0, 15.0, '9', '7', 12.0, 11.0, 14.0, 16.0,
#        20.0, '77', 13.0, '8', 25.0, '10', 19.0, '542', '1042', '27', '20',
#        30.0, '170', '87', '94', '71', '632', 18.0, 32.0, '80', '211',
#        24.0, 31.0, 21.0, 29.0, '218', 27.0, 23.0, '40', 28.0],
#       dtype=object)

# %%
#repetimos nuevamente para ver cuántos son los valores que tenemos
len(df.loc[df.rooms == ''])
# Out:
# 32184

# %%
#limpiamos los valores atípicos que nos faltaban
df.rooms=df.rooms.replace('3',3.0).replace('1',1.0).replace('4',4.0).replace('5',5.0).replace('6',6.0)
df.rooms=df.rooms.replace(17.0,'').replace(22.0,'').replace(15.0,'').replace('9',9.0).replace(12.0,'')
df.rooms=df.rooms.replace(11.0,'').replace(14.0,'').replace(16.0,'').replace(20.0,'').replace('77','')
df.rooms=df.rooms.replace(13.0,'').replace('8',8.0).replace(25.0,'').replace('10',10.0).replace(19.0,'')
df.rooms=df.rooms.replace('542','').replace('1042','').replace('27','').replace('20','')
df.rooms=df.rooms.replace(30.0,'').replace('170','').replace('87','').replace('94','')
df.rooms=df.rooms.replace('71','').replace('632','').replace(18.0,'').replace(32.0,'')
df.rooms=df.rooms.replace('80','').replace('211','').replace(24.0,'').replace(31.0,'')
df.rooms=df.rooms.replace(21.0,'').replace(29.0,'').replace('218','').replace(27.0,'').replace(23.0,'')
df.rooms=df.rooms.replace('40','').replace(28.0,'').replace('7',7.0)

# %%
#vemos que todos los valores son floats
df['rooms'].unique()
# Out:
# array([2.0, 3.0, '', 1.0, 4.0, 6.0, 5.0, 10.0, 7.0, 9.0, 8.0],
#       dtype=object)

# %%
#nos quedamos con 32522 registros de ambientes para la columna 'rooms'
len(df.loc[df.rooms == ''])
# Out:
# 32522

# %%
#ahora transformamos los '' en NaN para que toda la columna 'rooms' vuelva a tener valores Floats únicamente
df.rooms=df.rooms.replace('',np.NaN)

# %%
#y chequeamos que la col 'rooms' efectivamente tiene todos Floats
df.head(12)
# Out:
#    operation property_type    place_name  \
# 0       sell            PH     Mataderos
# 1       sell     apartment      La Plata
# 2       sell     apartment     Mataderos
# 3       sell            PH       Liniers
# 4       sell     apartment        Centro
# 5       sell         house  Gualeguaychú
# 6       sell            PH         Munro
# 7       sell     apartment      Belgrano
# 8       sell     apartment      Belgrano
# 9       sell         house       Rosario
# 10      sell         house       Córdoba
# 11      sell         house    San Miguel
#
#                               place_with_parent_names country_name  \
# 0               |Argentina|Capital Federal|Mataderos|    Argentina
# 1         |Argentina|Bs.As. G.B.A. Zona Sur|La Plata|    Argentina
# 2               |Argentina|Capital Federal|Mataderos|    Argentina
# 3                 |Argentina|Capital Federal|Liniers|    Argentina
# 4   |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
# 5                 |Argentina|Entre Ríos|Gualeguaychú|    Argentina
# 6   |Argentina|Bs.As. G.B.A. Zona Norte|Vicente Ló...    Argentina
# 7                |Argentina|Capital Federal|Belgrano|    Argentina
# 8                |Argentina|Capital Federal|Belgrano|    Argentina
# 9                        |Argentina|Santa Fe|Rosario|    Argentina
# 10                        |Argentina|Córdoba|Córdoba|    Argentina
# 11    |Argentina|Bs.As. G.B.A. Zona Norte|San Miguel|    Argentina
#
#                       state_name  geonames_id                  lat-lon  \
# 0                Capital Federal    3430787.0  -34.6618237,-58.5088387
# 1         Bs.As. G.B.A. Zona Sur    3432039.0  -34.9038831,-57.9643295
# 2                Capital Federal    3430787.0  -34.6522615,-58.5229825
# 3                Capital Federal    3431333.0  -34.6477969,-58.5164244
# 4   Buenos Aires Costa Atlántica    3435548.0  -38.0026256,-57.5494468
# 5                     Entre Ríos    3433657.0   -33.0140714,-58.519828
# 6       Bs.As. G.B.A. Zona Norte    3430511.0  -34.5329567,-58.5217825
# 7                Capital Federal    3436077.0   -34.5598729,-58.443362
# 8                Capital Federal    3436077.0   -34.5598729,-58.443362
# 9                       Santa Fe    3838574.0   -32.942031,-60.7259192
# 10                       Córdoba    3860259.0  -31.4200833,-64.1887761
# 11      Bs.As. G.B.A. Zona Norte          NaN  -34.5390571,-58.7196093
#
#           lat        lon  ...  floor rooms  expenses  \
# 0  -34.661824 -58.508839  ...    NaN   2.0       NaN
# 1  -34.903883 -57.964330  ...    NaN   2.0       NaN
# 2  -34.652262 -58.522982  ...    NaN   2.0       NaN
# 3  -34.647797 -58.516424  ...    NaN   3.0       NaN
# 4  -38.002626 -57.549447  ...    NaN   2.0       NaN
# 5  -33.014071 -58.519828  ...    NaN   NaN       NaN
# 6  -34.532957 -58.521782  ...    NaN   NaN       NaN
# 7  -34.559873 -58.443362  ...    NaN   NaN       NaN
# 8  -34.559873 -58.443362  ...    NaN   NaN       NaN
# 9  -32.942031 -60.725919  ...    NaN   2.0       NaN
# 10 -31.420083 -64.188776  ...    NaN   3.0       NaN
# 11 -34.539057 -58.719609  ...    NaN   NaN       NaN
#
#                                         properati_url  \
# 0   http://www.properati.com.ar/15bo8_venta_ph_mat...
# 1   http://www.properati.com.ar/15bob_venta_depart...
# 2   http://www.properati.com.ar/15bod_venta_depart...
# 3   http://www.properati.com.ar/15boh_venta_ph_lin...
# 4   http://www.properati.com.ar/15bok_venta_depart...
# 5   http://www.properati.com.ar/15bop_venta_depart...
# 6   http://www.properati.com.ar/15bor_venta_ph_mun...
# 7   http://www.properati.com.ar/15bot_venta_depart...
# 8   http://www.properati.com.ar/15bou_venta_depart...
# 9   http://www.properati.com.ar/15box_venta_casa_r...
# 10  http://www.properati.com.ar/15boy_venta_casa_c...
# 11  http://www.properati.com.ar/15bp0_venta_casa_s...
#
#                                           description  \
# 0   2 AMBIENTES TIPO CASA PLANTA BAJA POR PASILLO,...
# 1   Venta de departamento en décimo piso al frente...
# 2   2 AMBIENTES 3ER PISO LATERAL LIVING COMEDOR AM...
# 3   PH 3 ambientes con patio. Hay 3 deptos en lote...
# 4   DEPARTAMENTO CON FANTÁSTICA ILUMINACIÓN NATURA...
# 5   Casa en el perímetro del barrio 338, ubicada e...
# 6   MUY BUEN PH AL FRENTE CON ENTRADA INDEPENDIENT...
# 7   EXCELENTE MONOAMBIENTE A ESTRENAR AMPLIO SUPER...
# 8   EXCELENTE DOS AMBIENTES  ESTRENAR AMPLIO SUPER...
# 9   MEDNOZA AL 7600A UNA CUADRA DE CALLE MENDOZAWH...
# 10  Hermosa casa sin terminar de 3 dormitorios, ba...
# 11  Entrada de Coche, Jardin, Living en desnivel, ...
#
#                                                 title  \
# 0                  2 AMB TIPO CASA SIN EXPENSAS EN PB
# 1   VENTA Depto 2 dorm. a estrenar 7 e/ 36 y 37   ...
# 2            2 AMB 3ER PISO CON ASCENSOR APTO CREDITO
# 3                        PH 3 amb. cfte. reciclado
# 4   DEPTO 2 AMB AL CONTRAFRENTE ZONA CENTRO/PLAZA ...
# 5   Casa Barrio 338. Sobre calle 3 de caballería, ...
# 6   MUY BUEN PH AL FRENTE DOS DORMITORIOS , PATIO,...
# 7   JOSE HERNANDEZ 1400 MONOAMBIENTE  ESTRENAR CAT...
# 8   JOSE HERNANDEZ   1400 DOS AMBIENTES ESTRENAR ,...
# 9          WHITE 7637 - 2 DORMITORIOS CON PATIO
# 10  Casa sin terminar en Falda de Cañete.         ...
# 11                                            CHALET
#
#                                       image_thumbnail     id  ambientes_tit  \
# 0   https://thumbs4.properati.com/8/BluUYiHJLhgIIK...  15bo8              2
# 1   https://thumbs4.properati.com/7/ikpVBu2ztHA7jv...  15bob              2
# 2   https://thumbs4.properati.com/5/SXKr34F_IwG3W_...  15bod              2
# 3   https://thumbs4.properati.com/3/DgIfX-85Mog5SP...  15boh              3
# 4   https://thumbs4.properati.com/5/xrRqlNcSI_vs-f...  15bok              2
# 5   https://thumbs4.properati.com/6/q-w68gvaUEQVXI...  15bop
# 6   https://thumbs4.properati.com/5/6GOXsHCyDu1aGx...  15bor
# 7   https://thumbs4.properati.com/1/IHxARynlr8sPEW...  15bot
# 8   https://thumbs4.properati.com/2/J3zOjgaFHrkvnv...  15bou
# 9   https://thumbs4.properati.com/8/RCf1YEWdF4rv98...  15box              2
# 10  https://thumbs4.properati.com/3/mQkhIxXpTTbMSc...  15boy
# 11  https://thumbs4.properati.com/4/pH0MnS_2zCGOHR...  15bp0
#
#     ambientes_descrip
# 0                   2
# 1
# 2                   2
# 3                   3
# 4                   1
# 5
# 6
# 7
# 8
# 9                   2
# 10                  3
# 11                 12
#
# [12 rows x 28 columns]

# %%
df['rooms'].unique()
# Out:
# array([ 2.,  3., nan,  1.,  4.,  6.,  5., 10.,  7.,  9.,  8.])

# %%
df.loc[7367]
# Out:
# operation                                                                  sell
# property_type                                                             house
# place_name                                                coordenadas 34.255511
# place_with_parent_names       |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|coor...
# country_name                                                          Argentina
# state_name                                             Bs.As. G.B.A. Zona Norte
# geonames_id                                                                 NaN
# lat-lon                                           -34.4284852743,-58.6017169869
# lat                                                                    -34.4285
# lon                                                                    -58.6017
# price                                                                    550000
# currency                                                                    USD
# price_aprox_local_currency                                          9.70448e+06
# price_aprox_usd                                                          550000
# surface_total_in_m2                                                         283
# surface_covered_in_m2                                                       239
# price_usd_per_m2                                                        1943.46
# price_per_m2                                                            2301.26
# floor                                                                       NaN
# rooms                                                                         2
# expenses                                                                    NaN
# properati_url                 http://www.properati.com.ar/15xo4_venta_casa_c...
# description                   PLANTA BAJA: Hall y toilette de recepción. Liv...
# title                                Hermosa casa sobre la laguna en Los Ombues
# image_thumbnail               https://thumbs4.properati.com/6/RN1XpmMmqDz7b6...
# id                                                                        15xo4
# ambientes_tit
# ambientes_descrip                                                             2
# Name: 7367, dtype: object
